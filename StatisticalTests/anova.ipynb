# %% [markdown]
# # ANOVA Testing

# %% [markdown]
# ## Variables:
# - Size of model (tiny or base)
# - Use of perspective transformation (prePT or PT)
# - Use of HHA encoding
# - Use of simulated data

# %%
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
import seaborn as sns
import itertools
import statsmodels.api as sm
from statsmodels.formula.api import ols
from glob import glob
import os

# %% [markdown]
# ## Data Preparation

# %%
files = glob('./*.csv')
print(files)
df = pd.concat([pd.read_csv(fp).assign(Vars=os.path.basename(fp)[:-4]) for fp in files], ignore_index=True)
df.sample(5)
# Out:
# ['.\\ViT_Base_HHA.csv', '.\\ViT_Base_HHA_PT.csv', '.\\ViT_Base_prePT.csv', '.\\ViT_Base_PT.csv', '.\\ViT_Base_Sim_HHA.csv', '.\\ViT_Base_Sim_HHA_PT.csv', '.\\ViT_Base_Sim_prePT.csv', '.\\ViT_Base_Sim_PT.csv', '.\\ViT_Tiny_HHA.csv', '.\\ViT_Tiny_HHA_PT.csv', '.\\ViT_Tiny_prePT.csv', '.\\ViT_Tiny_PT.csv', '.\\ViT_Tiny_Sim_HHA.csv', '.\\ViT_Tiny_Sim_HHA_PT.csv', '.\\ViT_Tiny_Sim_prePT.csv', '.\\ViT_Tiny_Sim_PT.csv']
#       TP  FP  FN    TN  Specificity  Sensitivity  Precision  Accuracy  \
# 250  172  12  21   944     0.987448     0.891192   0.934783  0.971279
# 260  170  16  23  2421     0.993435     0.880829   0.913978  0.985171
# 384  206  85  38  2763     0.970154     0.844262   0.707904  0.960220
# 64   211  10  33  2838     0.996489     0.864754   0.954751  0.986093
# 173  157  25  48  3239     0.992341     0.765854   0.862637  0.978956
#
#            F1       MCC                Vars
# 250  0.912467  0.895665      ViT_Tiny_prePT
# 260  0.897098  0.889287      ViT_Tiny_prePT
# 384  0.770093  0.751984     ViT_Tiny_Sim_PT
# 64   0.907527  0.901318      ViT_Base_prePT
# 173  0.811370  0.801857  ViT_Base_Sim_prePT

# %%
df.describe()
# Out:
#                TP          FP          FN            TN  Specificity  \
# count  400.000000  400.000000  400.000000    400.000000   400.000000
# mean   206.480000   42.215000   45.270000   2753.402500     0.984150
# std     49.073007   51.627777   26.963302   1518.248402     0.019744
# min     31.000000    0.000000    5.000000    944.000000     0.841158
# 25%    168.000000   17.000000   28.000000   2435.750000     0.982315
# 50%    204.000000   27.000000   41.000000   2504.000000     0.990169
# 75%    252.000000   45.000000   56.000000   2833.250000     0.994031
# max    300.000000  406.000000  285.000000  32350.000000     1.000000
#
#        Sensitivity   Precision    Accuracy          F1         MCC
# count   400.000000  400.000000  400.000000  400.000000  400.000000
# mean      0.819516    0.854490    0.970581    0.829584    0.817741
# std       0.101534    0.102361    0.020183    0.088897    0.088936
# min       0.098101    0.361552    0.840181    0.178161    0.291292
# 25%       0.771325    0.835424    0.966723    0.794814    0.777987
# 50%       0.844082    0.883444    0.975209    0.851907    0.836716
# 75%       0.885246    0.916065    0.982516    0.885285    0.875028
# max       0.974093    1.000000    0.997974    0.939086    0.934594

# %%
df.loc[df['Vars'].str.contains('Base'), 'model_size'] = 'Base'
df.loc[df['Vars'].str.contains('Tiny'), 'model_size'] = 'Tiny'
df.loc[df['Vars'].str.contains('HHA'), 'Encoding'] = 'HHA'
df.loc[df['Vars'].str.contains('HHA') == False, 'Encoding'] = 'Depth'
df.loc[df['Vars'].str.contains('prePT') | (df['Vars'].str.contains('PT') == False), 'Transformation'] = 'None'
df.loc[(df['Vars'].str.contains('prePT') == False) & df['Vars'].str.contains('PT'), 'Transformation'] = 'PT'
df.loc[df['Vars'].str.contains('Sim'), 'Simulated_Data'] = 'Sim'
df.loc[df['Vars'].str.contains('Sim') == False, 'Simulated_Data'] = 'None'

del df['Vars']

# %%
df.sample(5)
# Out:
#       TP  FP  FN    TN  Specificity  Sensitivity  Precision  Accuracy  \
# 319  219  22  25  2826     0.992275     0.897541   0.908714  0.984799
# 320  177  15  16  2422     0.993845     0.917098   0.921875  0.988213
# 230  180  18  13  2419     0.992614     0.932642   0.909091  0.988213
# 374  209  30  35  2818     0.989466     0.856557   0.874477  0.978978
# 361  263  44  53  2512     0.982786     0.832278   0.856678  0.966226
#
#            F1       MCC model_size Encoding Transformation Simulated_Data
# 319  0.903093  0.894866       Tiny      HHA           None            Sim
# 320  0.919481  0.913125       Tiny      HHA           None            Sim
# 230  0.920716  0.914438       Tiny      HHA             PT           None
# 374  0.865424  0.854078       Tiny    Depth           None            Sim
# 361  0.844302  0.825473       Tiny    Depth           None            Sim

# %%
metrics = ['Specificity', 'Sensitivity', 'Precision', 'Accuracy', 'F1', 'MCC']
vars = ['model_size', 'Encoding', 'Transformation', 'Simulated_Data']
var_pairs = list(itertools.combinations(vars, 2))

for metric in metrics:
    print(f'Two-way ANOVA tests for {metric}:\n')
    for (var1, var2) in var_pairs:
        model = ols(f'{metric} ~ C({var1}) + C({var2}) + C({var1}):C({var2})', data=df).fit()

        result = sm.stats.anova_lm(model, type=2)

        print(result, '\n')
# Out:
# Two-way ANOVA tests for Specificity:
#
#                               df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                1.0  0.001828  0.001828  4.781173  0.029357
# C(Encoding)                  1.0  0.002199  0.002199  5.752307  0.016929
# C(model_size):C(Encoding)    1.0  0.000104  0.000104  0.273229  0.601466
# Residual                   396.0  0.151406  0.000382       NaN       NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.001828  0.001828  4.758571  0.029740
# C(Transformation)                  1.0  0.001578  0.001578  4.108112  0.043348
# C(model_size):C(Transformation)    1.0  0.000006  0.000006  0.016916  0.896584
# Residual                         396.0  0.152125  0.000384       NaN       NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.001828  0.001828  4.783325  0.029321
# C(Simulated_Data)                  1.0  0.001618  0.001618  4.234242  0.040270
# C(model_size):C(Simulated_Data)    1.0  0.000754  0.000754  1.972235  0.160995
# Residual                         396.0  0.151338  0.000382       NaN       NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.002199  0.002199  5.746798  0.016981
# C(Transformation)                1.0  0.001578  0.001578  4.123672  0.042955
# C(Encoding):C(Transformation)    1.0  0.000209  0.000209  0.546700  0.460107
# Residual                       396.0  0.151551  0.000383       NaN       NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.002199  0.002199  5.777892  0.016688
# C(Simulated_Data)                1.0  0.001618  0.001618  4.251162  0.039875
# C(Encoding):C(Simulated_Data)    1.0  0.000985  0.000985  2.587068  0.108537
# Residual                       396.0  0.150735  0.000381       NaN       NaN
#
#                                         df    sum_sq   mean_sq         F  \
# C(Transformation)                      1.0  0.001578  0.001578  4.102532
# C(Simulated_Data)                      1.0  0.001618  0.001618  4.206608
# C(Transformation):C(Simulated_Data)    1.0  0.000009  0.000009  0.024522
# Residual                             396.0  0.152332  0.000385       NaN
#
#                                        PR(>F)
# C(Transformation)                    0.043489
# C(Simulated_Data)                    0.040924
# C(Transformation):C(Simulated_Data)  0.875645
# Residual                                  NaN
#
# Two-way ANOVA tests for Sensitivity:
#
#                               df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                1.0  0.089944  0.089944  9.024040  0.002834
# C(Encoding)                  1.0  0.039752  0.039752  3.988317  0.046501
# C(model_size):C(Encoding)    1.0  0.036692  0.036692  3.681272  0.055745
# Residual                   396.0  3.946986  0.009967       NaN       NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.089944  0.089944  8.877632  0.003065
# C(Transformation)                  1.0  0.005826  0.005826  0.575035  0.448716
# C(model_size):C(Transformation)    1.0  0.005525  0.005525  0.545344  0.460664
# Residual                         396.0  4.012078  0.010132       NaN       NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.089944  0.089944  8.868596  0.003080
# C(Simulated_Data)                  1.0  0.005741  0.005741  0.566096  0.452261
# C(model_size):C(Simulated_Data)    1.0  0.001522  0.001522  0.150052  0.698694
# Residual                         396.0  4.016166  0.010142       NaN       NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.039752  0.039752  3.964604  0.047153
# C(Transformation)                1.0  0.005826  0.005826  0.581043  0.446357
# C(Encoding):C(Transformation)    1.0  0.097202  0.097202  9.694309  0.001983
# Residual                       396.0  3.970593  0.010027       NaN       NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.039752  0.039752  3.878182  0.049614
# C(Simulated_Data)                1.0  0.005741  0.005741  0.560112  0.454659
# C(Encoding):C(Simulated_Data)    1.0  0.008806  0.008806  0.859080  0.354561
# Residual                       396.0  4.059074  0.010250       NaN       NaN
#
#                                         df    sum_sq   mean_sq         F  \
# C(Transformation)                      1.0  0.005826  0.005826  0.562699
# C(Simulated_Data)                      1.0  0.005741  0.005741  0.554516
# C(Transformation):C(Simulated_Data)    1.0  0.001767  0.001767  0.170673
# Residual                             396.0  4.100039  0.010354       NaN
#
#                                        PR(>F)
# C(Transformation)                    0.453620
# C(Simulated_Data)                    0.456920
# C(Transformation):C(Simulated_Data)  0.679738
# Residual                                  NaN
#
# Two-way ANOVA tests for Precision:
#
#                               df        sum_sq       mean_sq          F  \
# C(model_size)                1.0  8.458348e-02  8.458348e-02   8.496976
# C(Encoding)                  1.0  1.540517e-01  1.540517e-01  15.475523
# C(model_size):C(Encoding)    1.0  3.114812e-07  3.114812e-07   0.000031
# Residual                   396.0  3.941998e+00  9.954540e-03        NaN
#
#                              PR(>F)
# C(model_size)              0.003759
# C(Encoding)                0.000099
# C(model_size):C(Encoding)  0.995540
# Residual                        NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.084583  0.084583  8.214156  0.004378
# C(Transformation)                  1.0  0.016422  0.016422  1.594822  0.207382
# C(model_size):C(Transformation)    1.0  0.001904  0.001904  0.184877  0.667449
# Residual                         396.0  4.077724  0.010297       NaN       NaN
#
#                                     df    sum_sq   mean_sq         F    PR(>F)
# C(model_size)                      1.0  0.084583  0.084583  8.430288  0.003897
# C(Simulated_Data)                  1.0  0.087886  0.087886  8.759409  0.003265
# C(model_size):C(Simulated_Data)    1.0  0.034983  0.034983  3.486731  0.062601
# Residual                         396.0  3.973181  0.010033       NaN       NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.154052  0.154052  15.277725  0.000109
# C(Transformation)                1.0  0.016422  0.016422   1.628647  0.202638
# C(Encoding):C(Transformation)    1.0  0.017125  0.017125   1.698349  0.193261
# Residual                       396.0  3.993034  0.010083        NaN       NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.154052  0.154052  15.774577  0.000085
# C(Simulated_Data)                1.0  0.087886  0.087886   8.999309  0.002872
# C(Encoding):C(Simulated_Data)    1.0  0.071431  0.071431   7.314341  0.007136
# Residual                       396.0  3.867265  0.009766        NaN       NaN
#
#                                         df    sum_sq   mean_sq         F  \
# C(Transformation)                      1.0  0.016422  0.016422  1.596465
# C(Simulated_Data)                      1.0  0.087886  0.087886  8.543631
# C(Transformation):C(Simulated_Data)    1.0  0.002798  0.002798  0.271992
# Residual                             396.0  4.073528  0.010287       NaN
#
#                                        PR(>F)
# C(Transformation)                    0.207148
# C(Simulated_Data)                    0.003666
# C(Transformation):C(Simulated_Data)  0.602290
# Residual                                  NaN
#
# Two-way ANOVA tests for Accuracy:
#
#                               df    sum_sq   mean_sq          F    PR(>F)
# C(model_size)                1.0  0.004243  0.004243  10.827558  0.001090
# C(Encoding)                  1.0  0.003027  0.003027   7.724538  0.005707
# C(model_size):C(Encoding)    1.0  0.000096  0.000096   0.245351  0.620643
# Residual                   396.0  0.155163  0.000392        NaN       NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.004243  0.004243  10.698466
# C(Transformation)                  1.0  0.001192  0.001192   3.004945
# C(model_size):C(Transformation)    1.0  0.000059  0.000059   0.148600
# Residual                         396.0  0.157036  0.000397        NaN
#
#                                    PR(>F)
# C(model_size)                    0.001166
# C(Transformation)                0.083789
# C(model_size):C(Transformation)  0.700083
# Residual                              NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.004243  0.004243  10.766347
# C(Simulated_Data)                  1.0  0.001778  0.001778   4.511206
# C(model_size):C(Simulated_Data)    1.0  0.000463  0.000463   1.174957
# Residual                         396.0  0.156046  0.000394        NaN
#
#                                    PR(>F)
# C(model_size)                    0.001125
# C(Simulated_Data)                0.034293
# C(model_size):C(Simulated_Data)  0.279044
# Residual                              NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.003027  0.003027  7.661706  0.005905
# C(Transformation)                1.0  0.001192  0.001192  3.016466  0.083201
# C(Encoding):C(Transformation)    1.0  0.001875  0.001875  4.745279  0.029968
# Residual                       396.0  0.156436  0.000395       NaN       NaN
#
#                                   df    sum_sq   mean_sq         F    PR(>F)
# C(Encoding)                      1.0  0.003027  0.003027  7.618765  0.006045
# C(Simulated_Data)                1.0  0.001778  0.001778  4.474730  0.035024
# C(Encoding):C(Simulated_Data)    1.0  0.000407  0.000407  1.024044  0.312180
# Residual                       396.0  0.157318  0.000397       NaN       NaN
#
#                                         df        sum_sq       mean_sq  \
# C(Transformation)                      1.0  1.191625e-03  1.191625e-03
# C(Simulated_Data)                      1.0  1.777661e-03  1.777661e-03
# C(Transformation):C(Simulated_Data)    1.0  2.220091e-07  2.220091e-07
# Residual                             396.0  1.595593e-01  4.029274e-04
#
#                                             F    PR(>F)
# C(Transformation)                    2.957419  0.086266
# C(Simulated_Data)                    4.411864  0.036322
# C(Transformation):C(Simulated_Data)  0.000551  0.981285
# Residual                                  NaN       NaN
#
# Two-way ANOVA tests for F1:
#
#                               df    sum_sq   mean_sq          F    PR(>F)
# C(model_size)                1.0  0.087045  0.087045  11.621314  0.000719
# C(Encoding)                  1.0  0.084410  0.084410  11.269489  0.000864
# C(model_size):C(Encoding)    1.0  0.015659  0.015659   2.090603  0.148999
# Residual                   396.0  2.966083  0.007490        NaN       NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.087045  0.087045  11.295199
# C(Transformation)                  1.0  0.006058  0.006058   0.786151
# C(model_size):C(Transformation)    1.0  0.008374  0.008374   1.086581
# Residual                         396.0  3.051719  0.007706        NaN
#
#                                    PR(>F)
# C(model_size)                    0.000853
# C(Transformation)                0.375805
# C(model_size):C(Transformation)  0.297866
# Residual                              NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.087045  0.087045  11.465990
# C(Simulated_Data)                  1.0  0.056296  0.056296   7.415596
# C(model_size):C(Simulated_Data)    1.0  0.003593  0.003593   0.473223
# Residual                         396.0  3.006263  0.007592        NaN
#
#                                    PR(>F)
# C(model_size)                    0.000780
# C(Simulated_Data)                0.006752
# C(model_size):C(Simulated_Data)  0.491911
# Residual                              NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.084410  0.084410  11.174160  0.000908
# C(Transformation)                1.0  0.006058  0.006058   0.802006  0.371038
# C(Encoding):C(Transformation)    1.0  0.071341  0.071341   9.444157  0.002265
# Residual                       396.0  2.991387  0.007554        NaN       NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.084410  0.084410  11.108067  0.000940
# C(Simulated_Data)                1.0  0.056296  0.056296   7.408393  0.006779
# C(Encoding):C(Simulated_Data)    1.0  0.003305  0.003305   0.434902  0.509977
# Residual                       396.0  3.009186  0.007599        NaN       NaN
#
#                                         df    sum_sq   mean_sq         F  \
# C(Transformation)                      1.0  0.006058  0.006058  0.776528
# C(Simulated_Data)                      1.0  0.056296  0.056296  7.215719
# C(Transformation):C(Simulated_Data)    1.0  0.001305  0.001305  0.167248
# Residual                             396.0  3.089537  0.007802       NaN
#
#                                        PR(>F)
# C(Transformation)                    0.378740
# C(Simulated_Data)                    0.007531
# C(Transformation):C(Simulated_Data)  0.682791
# Residual                                  NaN
#
# Two-way ANOVA tests for MCC:
#
#                               df    sum_sq   mean_sq          F    PR(>F)
# C(model_size)                1.0  0.106892  0.106892  14.432046  0.000168
# C(Encoding)                  1.0  0.102389  0.102389  13.824036  0.000230
# C(model_size):C(Encoding)    1.0  0.013652  0.013652   1.843209  0.175348
# Residual                   396.0  2.933001  0.007407        NaN       NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.106892  0.106892  13.932773
# C(Transformation)                  1.0  0.004688  0.004688   0.610998
# C(model_size):C(Transformation)    1.0  0.006250  0.006250   0.814708
# Residual                         396.0  3.038103  0.007672        NaN
#
#                                    PR(>F)
# C(model_size)                    0.000217
# C(Transformation)                0.434879
# C(model_size):C(Transformation)  0.367281
# Residual                              NaN
#
#                                     df    sum_sq   mean_sq          F  \
# C(model_size)                      1.0  0.106892  0.106892  14.158046
# C(Simulated_Data)                  1.0  0.053505  0.053505   7.086821
# C(model_size):C(Simulated_Data)    1.0  0.005773  0.005773   0.764694
# Residual                         396.0  2.989763  0.007550        NaN
#
#                                    PR(>F)
# C(model_size)                    0.000193
# C(Simulated_Data)                0.008082
# C(model_size):C(Simulated_Data)  0.382393
# Residual                              NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.102389  0.102389  13.615826  0.000256
# C(Transformation)                1.0  0.004688  0.004688   0.623361  0.430274
# C(Encoding):C(Transformation)    1.0  0.071005  0.071005   9.442415  0.002267
# Residual                       396.0  2.977851  0.007520        NaN       NaN
#
#                                   df    sum_sq   mean_sq          F    PR(>F)
# C(Encoding)                      1.0  0.102389  0.102389  13.545537  0.000265
# C(Simulated_Data)                1.0  0.053505  0.053505   7.078437  0.008119
# C(Encoding):C(Simulated_Data)    1.0  0.006736  0.006736   0.891103  0.345754
# Residual                       396.0  2.993304  0.007559        NaN       NaN
#
#                                         df    sum_sq   mean_sq         F  \
# C(Transformation)                      1.0  0.004688  0.004688  0.599271
# C(Simulated_Data)                      1.0  0.053505  0.053505  6.840209
# C(Transformation):C(Simulated_Data)    1.0  0.000187  0.000187  0.023917
# Residual                             396.0  3.097553  0.007822       NaN
#
#                                        PR(>F)
# C(Transformation)                    0.439318
# C(Simulated_Data)                    0.009253
# C(Transformation):C(Simulated_Data)  0.877176
# Residual                                  NaN

# %%
metrics = ['Specificity', 'Sensitivity', 'Precision', 'Accuracy', 'F1', 'MCC']
vars = ['model_size', 'Encoding', 'Transformation', 'Simulated_Data']
var_pairs = list(itertools.combinations(vars, 2))
var_trips = list(itertools.combinations(vars, 3))

modelString = ''
for var in vars:
    modelString = modelString + f' + C({var})'

for (var1, var2) in var_pairs:
    modelString = modelString + f' + C({var1}):C({var2})'

for (var1, var2, var3) in var_trips:
    modelString = modelString + f' + C({var1}):C({var2}):C({var3})'

modelString = modelString + f' + C({vars[0]}):C({vars[1]}):C({vars[2]}):C({vars[3]})'

for metric in metrics:
    print(f'Multivariate ANOVA tests for {metric}:\n')
    model = ols(f'{metric} ~ {modelString}', data=df).fit()

    result = sm.stats.anova_lm(model, type=2)

    print(result, '\n')
# Out:
# Multivariate ANOVA tests for Specificity:
#
#                                                        df    sum_sq   mean_sq  \
# C(model_size)                                         1.0  0.001828  0.001828
# C(Encoding)                                           1.0  0.002199  0.002199
# C(Transformation)                                     1.0  0.001578  0.001578
# C(Simulated_Data)                                     1.0  0.001618  0.001618
# C(model_size):C(Encoding)                             1.0  0.000104  0.000104
# C(model_size):C(Transformation)                       1.0  0.000006  0.000006
# C(model_size):C(Simulated_Data)                       1.0  0.000754  0.000754
# C(Encoding):C(Transformation)                         1.0  0.000209  0.000209
# C(Encoding):C(Simulated_Data)                         1.0  0.000985  0.000985
# C(Transformation):C(Simulated_Data)                   1.0  0.000009  0.000009
# C(model_size):C(Encoding):C(Transformation)           1.0  0.001193  0.001193
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  0.000005  0.000005
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  0.000076  0.000076
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  0.000163  0.000163
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  0.002045  0.002045
# Residual                                            384.0  0.142763  0.000372
#
#                                                            F    PR(>F)
# C(model_size)                                       4.916969  0.027179
# C(Encoding)                                         5.915685  0.015463
# C(Transformation)                                   4.244858  0.040043
# C(Simulated_Data)                                   4.352545  0.037613
# C(model_size):C(Encoding)                           0.280990  0.596360
# C(model_size):C(Transformation)                     0.017479  0.894889
# C(model_size):C(Simulated_Data)                     2.027339  0.155303
# C(Encoding):C(Transformation)                       0.562767  0.453607
# C(Encoding):C(Simulated_Data)                       2.648765  0.104451
# C(Transformation):C(Simulated_Data)                 0.025372  0.873526
# C(model_size):C(Encoding):C(Transformation)         3.210188  0.073968
# C(model_size):C(Encoding):C(Simulated_Data)         0.014020  0.905807
# C(model_size):C(Transformation):C(Simulated_Data)   0.205529  0.650551
# C(Encoding):C(Transformation):C(Simulated_Data)     0.438767  0.508116
# C(model_size):C(Encoding):C(Transformation):C(S...  5.499650  0.019529
# Residual                                                 NaN       NaN
#
# Multivariate ANOVA tests for Sensitivity:
#
#                                                        df    sum_sq   mean_sq  \
# C(model_size)                                         1.0  0.089944  0.089944
# C(Encoding)                                           1.0  0.039752  0.039752
# C(Transformation)                                     1.0  0.005826  0.005826
# C(Simulated_Data)                                     1.0  0.005741  0.005741
# C(model_size):C(Encoding)                             1.0  0.036692  0.036692
# C(model_size):C(Transformation)                       1.0  0.005525  0.005525
# C(model_size):C(Simulated_Data)                       1.0  0.001522  0.001522
# C(Encoding):C(Transformation)                         1.0  0.097202  0.097202
# C(Encoding):C(Simulated_Data)                         1.0  0.008806  0.008806
# C(Transformation):C(Simulated_Data)                   1.0  0.001767  0.001767
# C(model_size):C(Encoding):C(Transformation)           1.0  0.003746  0.003746
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  0.004549  0.004549
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  0.001645  0.001645
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  0.000971  0.000971
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  0.016374  0.016374
# Residual                                            384.0  3.793312  0.009878
#
#                                                            F    PR(>F)
# C(model_size)                                       9.105086  0.002719
# C(Encoding)                                         4.024137  0.045554
# C(Transformation)                                   0.589768  0.442981
# C(Simulated_Data)                                   0.581192  0.446314
# C(model_size):C(Encoding)                           3.714334  0.054685
# C(model_size):C(Transformation)                     0.559316  0.454994
# C(model_size):C(Simulated_Data)                     0.154053  0.694910
# C(Encoding):C(Transformation)                       9.839878  0.001839
# C(Encoding):C(Simulated_Data)                       0.891411  0.345689
# C(Transformation):C(Simulated_Data)                 0.178884  0.672571
# C(model_size):C(Encoding):C(Transformation)         0.379226  0.538383
# C(model_size):C(Encoding):C(Simulated_Data)         0.460452  0.497822
# C(model_size):C(Transformation):C(Simulated_Data)   0.166525  0.683446
# C(Encoding):C(Transformation):C(Simulated_Data)     0.098253  0.754106
# C(model_size):C(Encoding):C(Transformation):C(S...  1.657582  0.198706
# Residual                                                 NaN       NaN
#
# Multivariate ANOVA tests for Precision:
#
#                                                        df        sum_sq  \
# C(model_size)                                         1.0  8.458348e-02
# C(Encoding)                                           1.0  1.540517e-01
# C(Transformation)                                     1.0  1.642234e-02
# C(Simulated_Data)                                     1.0  8.788565e-02
# C(model_size):C(Encoding)                             1.0  3.114812e-07
# C(model_size):C(Transformation)                       1.0  1.903736e-03
# C(model_size):C(Simulated_Data)                       1.0  3.498336e-02
# C(Encoding):C(Transformation)                         1.0  1.712516e-02
# C(Encoding):C(Simulated_Data)                         1.0  7.143055e-02
# C(Transformation):C(Simulated_Data)                   1.0  2.797899e-03
# C(model_size):C(Encoding):C(Transformation)           1.0  2.867631e-02
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  1.111732e-03
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  4.609420e-04
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  6.580156e-06
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  5.274716e-02
# Residual                                            384.0  3.626446e+00
#
#                                                          mean_sq          F  \
# C(model_size)                                       8.458348e-02   8.956442
# C(Encoding)                                         1.540517e-01  16.312348
# C(Transformation)                                   1.642234e-02   1.738941
# C(Simulated_Data)                                   8.788565e-02   9.306104
# C(model_size):C(Encoding)                           3.114812e-07   0.000033
# C(model_size):C(Transformation)                     1.903736e-03   0.201584
# C(model_size):C(Simulated_Data)                     3.498336e-02   3.704346
# C(Encoding):C(Transformation)                       1.712516e-02   1.813363
# C(Encoding):C(Simulated_Data)                       7.143055e-02   7.563694
# C(Transformation):C(Simulated_Data)                 2.797899e-03   0.296266
# C(model_size):C(Encoding):C(Transformation)         2.867631e-02   3.036499
# C(model_size):C(Encoding):C(Simulated_Data)         1.111732e-03   0.117720
# C(model_size):C(Transformation):C(Simulated_Data)   4.609420e-04   0.048809
# C(Encoding):C(Transformation):C(Simulated_Data)     6.580156e-06   0.000697
# C(model_size):C(Encoding):C(Transformation):C(S...  5.274716e-02   5.585333
# Residual                                            9.443871e-03        NaN
#
#                                                       PR(>F)
# C(model_size)                                       0.002944
# C(Encoding)                                         0.000065
# C(Transformation)                                   0.188059
# C(Simulated_Data)                                   0.002442
# C(model_size):C(Encoding)                           0.995421
# C(model_size):C(Transformation)                     0.653698
# C(model_size):C(Simulated_Data)                     0.055009
# C(Encoding):C(Transformation)                       0.178900
# C(Encoding):C(Simulated_Data)                       0.006237
# C(Transformation):C(Simulated_Data)                 0.586549
# C(model_size):C(Encoding):C(Transformation)         0.082212
# C(model_size):C(Encoding):C(Simulated_Data)         0.731708
# C(model_size):C(Transformation):C(Simulated_Data)   0.825267
# C(Encoding):C(Transformation):C(Simulated_Data)     0.978955
# C(model_size):C(Encoding):C(Transformation):C(S...  0.018609
# Residual                                                 NaN
#
# Multivariate ANOVA tests for Accuracy:
#
#                                                        df        sum_sq  \
# C(model_size)                                         1.0  4.242528e-03
# C(Encoding)                                           1.0  3.026681e-03
# C(Transformation)                                     1.0  1.191625e-03
# C(Simulated_Data)                                     1.0  1.777661e-03
# C(model_size):C(Encoding)                             1.0  9.613498e-05
# C(model_size):C(Transformation)                       1.0  5.892820e-05
# C(model_size):C(Simulated_Data)                       1.0  4.629972e-04
# C(Encoding):C(Transformation)                         1.0  1.874575e-03
# C(Encoding):C(Simulated_Data)                         1.0  4.068186e-04
# C(Transformation):C(Simulated_Data)                   1.0  2.220091e-07
# C(model_size):C(Encoding):C(Transformation)           1.0  6.598395e-04
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  4.553925e-05
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  1.353168e-04
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  2.154229e-04
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  8.899001e-04
# Residual                                            384.0  1.474446e-01
#
#                                                          mean_sq          F  \
# C(model_size)                                       4.242528e-03  11.049105
# C(Encoding)                                         3.026681e-03   7.882593
# C(Transformation)                                   1.191625e-03   3.103431
# C(Simulated_Data)                                   1.777661e-03   4.629684
# C(model_size):C(Encoding)                           9.613498e-05   0.250371
# C(model_size):C(Transformation)                     5.892820e-05   0.153471
# C(model_size):C(Simulated_Data)                     4.629972e-04   1.205815
# C(Encoding):C(Transformation)                       1.874575e-03   4.882085
# C(Encoding):C(Simulated_Data)                       4.068186e-04   1.059505
# C(Transformation):C(Simulated_Data)                 2.220091e-07   0.000578
# C(model_size):C(Encoding):C(Transformation)         6.598395e-04   1.718465
# C(model_size):C(Encoding):C(Simulated_Data)         4.553925e-05   0.118601
# C(model_size):C(Transformation):C(Simulated_Data)   1.353168e-04   0.352415
# C(Encoding):C(Transformation):C(Simulated_Data)     2.154229e-04   0.561041
# C(model_size):C(Encoding):C(Transformation):C(S...  8.899001e-04   2.317628
# Residual                                            3.839703e-04        NaN
#
#                                                       PR(>F)
# C(model_size)                                       0.000973
# C(Encoding)                                         0.005246
# C(Transformation)                                   0.078923
# C(Simulated_Data)                                   0.032046
# C(model_size):C(Encoding)                           0.617101
# C(model_size):C(Transformation)                     0.695458
# C(model_size):C(Simulated_Data)                     0.272851
# C(Encoding):C(Transformation)                       0.027726
# C(Encoding):C(Simulated_Data)                       0.303976
# C(Transformation):C(Simulated_Data)                 0.980829
# C(model_size):C(Encoding):C(Transformation)         0.190674
# C(model_size):C(Encoding):C(Simulated_Data)         0.730745
# C(model_size):C(Transformation):C(Simulated_Data)   0.553099
# C(Encoding):C(Transformation):C(Simulated_Data)     0.454300
# C(model_size):C(Encoding):C(Transformation):C(S...  0.128738
# Residual                                                 NaN
#
# Multivariate ANOVA tests for F1:
#
#                                                        df    sum_sq   mean_sq  \
# C(model_size)                                         1.0  0.087045  0.087045
# C(Encoding)                                           1.0  0.084410  0.084410
# C(Transformation)                                     1.0  0.006058  0.006058
# C(Simulated_Data)                                     1.0  0.056296  0.056296
# C(model_size):C(Encoding)                             1.0  0.015659  0.015659
# C(model_size):C(Transformation)                       1.0  0.008374  0.008374
# C(model_size):C(Simulated_Data)                       1.0  0.003593  0.003593
# C(Encoding):C(Transformation)                         1.0  0.071341  0.071341
# C(Encoding):C(Simulated_Data)                         1.0  0.003305  0.003305
# C(Transformation):C(Simulated_Data)                   1.0  0.001305  0.001305
# C(model_size):C(Encoding):C(Transformation)           1.0  0.002358  0.002358
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  0.005871  0.005871
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  0.003411  0.003411
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  0.003674  0.003674
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  0.002267  0.002267
# Residual                                            384.0  2.798231  0.007287
#
#                                                             F    PR(>F)
# C(model_size)                                       11.945133  0.000609
# C(Encoding)                                         11.583504  0.000735
# C(Transformation)                                    0.831386  0.362444
# C(Simulated_Data)                                    7.725480  0.005712
# C(model_size):C(Encoding)                            2.148856  0.143495
# C(model_size):C(Transformation)                      1.149103  0.284410
# C(model_size):C(Simulated_Data)                      0.492998  0.483018
# C(Encoding):C(Transformation)                        9.790126  0.001889
# C(Encoding):C(Simulated_Data)                        0.453516  0.501075
# C(Transformation):C(Simulated_Data)                  0.179063  0.672417
# C(model_size):C(Encoding):C(Transformation)          0.323542  0.569819
# C(model_size):C(Encoding):C(Simulated_Data)          0.805708  0.369955
# C(model_size):C(Transformation):C(Simulated_Data)    0.468059  0.494294
# C(Encoding):C(Transformation):C(Simulated_Data)      0.504198  0.478092
# C(model_size):C(Encoding):C(Transformation):C(S...   0.311056  0.577358
# Residual                                                  NaN       NaN
#
# Multivariate ANOVA tests for MCC:
#
#                                                        df    sum_sq   mean_sq  \
# C(model_size)                                         1.0  0.106892  0.106892
# C(Encoding)                                           1.0  0.102389  0.102389
# C(Transformation)                                     1.0  0.004688  0.004688
# C(Simulated_Data)                                     1.0  0.053505  0.053505
# C(model_size):C(Encoding)                             1.0  0.013652  0.013652
# C(model_size):C(Transformation)                       1.0  0.006250  0.006250
# C(model_size):C(Simulated_Data)                       1.0  0.005773  0.005773
# C(Encoding):C(Transformation)                         1.0  0.071005  0.071005
# C(Encoding):C(Simulated_Data)                         1.0  0.006736  0.006736
# C(Transformation):C(Simulated_Data)                   1.0  0.000187  0.000187
# C(model_size):C(Encoding):C(Transformation)           1.0  0.003722  0.003722
# C(model_size):C(Encoding):C(Simulated_Data)           1.0  0.004726  0.004726
# C(model_size):C(Transformation):C(Simulated_Data)     1.0  0.002690  0.002690
# C(Encoding):C(Transformation):C(Simulated_Data)       1.0  0.002069  0.002069
# C(model_size):C(Encoding):C(Transformation):C(S...    1.0  0.003746  0.003746
# Residual                                            384.0  2.767904  0.007208
#
#                                                             F    PR(>F)
# C(model_size)                                       14.829451  0.000138
# C(Encoding)                                         14.204698  0.000190
# C(Transformation)                                    0.650320  0.420497
# C(Simulated_Data)                                    7.422893  0.006734
# C(model_size):C(Encoding)                            1.893964  0.169558
# C(model_size):C(Transformation)                      0.867140  0.352333
# C(model_size):C(Simulated_Data)                      0.800958  0.371368
# C(Encoding):C(Transformation)                        9.850791  0.001829
# C(Encoding):C(Simulated_Data)                        0.934466  0.334313
# C(Transformation):C(Simulated_Data)                  0.025954  0.872098
# C(model_size):C(Encoding):C(Transformation)          0.516323  0.472852
# C(model_size):C(Encoding):C(Simulated_Data)          0.655617  0.418613
# C(model_size):C(Transformation):C(Simulated_Data)    0.373151  0.541653
# C(Encoding):C(Transformation):C(Simulated_Data)      0.287049  0.592428
# C(model_size):C(Encoding):C(Transformation):C(S...   0.519692  0.471412
# Residual                                                  NaN       NaN
