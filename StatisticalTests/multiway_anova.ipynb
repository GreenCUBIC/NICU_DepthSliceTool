# %% [markdown]
# # ANOVA Testing

# %% [markdown]
# ## Independant Variables:
#
# - Size of model (tiny or base)
# - Use of perspective transformation (prePT or PT)
# - Use of HHA encoding
# - Use of simulated data
#
# ## Dependant Variables (Metrics):
#
# - Specificity
# - Sensitivity
# - Precision
# - Accuracy
# - F1-Score
# - MCC

# %%
import pandas as pd
from tabulate import tabulate
import itertools
import statsmodels.api as sm
from statsmodels.multivariate.manova import MANOVA
from statsmodels.formula.api import ols
from glob import glob
import os

# %% [markdown]
# ## Data Preparation

# %%
files = glob('./*.csv')
print(files)
df = pd.concat([pd.read_csv(fp).assign(Vars=os.path.basename(fp)[:-4]) for fp in files], ignore_index=True)
df.sample(5)
# Out:
# ['.\\ViT_Base_HHA.csv', '.\\ViT_Base_HHA_PT.csv', '.\\ViT_Base_prePT.csv', '.\\ViT_Base_PT.csv', '.\\ViT_Base_Sim_HHA.csv', '.\\ViT_Base_Sim_HHA_PT.csv', '.\\ViT_Base_Sim_prePT.csv', '.\\ViT_Base_Sim_PT.csv', '.\\ViT_Tiny_HHA.csv', '.\\ViT_Tiny_HHA_PT.csv', '.\\ViT_Tiny_prePT.csv', '.\\ViT_Tiny_PT.csv', '.\\ViT_Tiny_Sim_HHA.csv', '.\\ViT_Tiny_Sim_HHA_PT.csv', '.\\ViT_Tiny_Sim_prePT.csv', '.\\ViT_Tiny_Sim_PT.csv']
#       TP   FP  FN    TN  Specificity  Sensitivity  Precision  Accuracy  \
# 297  265   55  37  2472     0.978235     0.877483   0.828125  0.967480
# 311  291  211  25  2345     0.917449     0.920886   0.579681  0.917827
# 67   269  178  33  2349     0.929561     0.890728   0.601790  0.925415
# 114  205   11  39  2837     0.996138     0.840164   0.949074  0.983829
# 340  170   16  23  2421     0.993435     0.880829   0.913978  0.985171
#
#            F1       MCC                 Vars
# 297  0.852090  0.834280          ViT_Tiny_PT
# 311  0.711491  0.690742     ViT_Tiny_Sim_HHA
# 67   0.718291  0.694462       ViT_Base_prePT
# 114  0.891304  0.884518     ViT_Base_Sim_HHA
# 340  0.897098  0.889287  ViT_Tiny_Sim_HHA_PT

# %%
df.describe()
# Out:
#                TP          FP          FN            TN  Specificity  \
# count  400.000000  400.000000  400.000000    400.000000   400.000000
# mean   206.480000   42.215000   45.270000   2753.402500     0.984150
# std     49.073007   51.627777   26.963302   1518.248402     0.019744
# min     31.000000    0.000000    5.000000    944.000000     0.841158
# 25%    168.000000   17.000000   28.000000   2435.750000     0.982315
# 50%    204.000000   27.000000   41.000000   2504.000000     0.990169
# 75%    252.000000   45.000000   56.000000   2833.250000     0.994031
# max    300.000000  406.000000  285.000000  32350.000000     1.000000
#
#        Sensitivity   Precision    Accuracy          F1         MCC
# count   400.000000  400.000000  400.000000  400.000000  400.000000
# mean      0.819516    0.854490    0.970581    0.829584    0.817741
# std       0.101534    0.102361    0.020183    0.088897    0.088936
# min       0.098101    0.361552    0.840181    0.178161    0.291292
# 25%       0.771325    0.835424    0.966723    0.794814    0.777987
# 50%       0.844082    0.883444    0.975209    0.851907    0.836716
# 75%       0.885246    0.916065    0.982516    0.885285    0.875028
# max       0.974093    1.000000    0.997974    0.939086    0.934594

# %%
df.loc[df['Vars'].str.contains('Base'), 'model_size'] = 'Base'
df.loc[df['Vars'].str.contains('Tiny'), 'model_size'] = 'Tiny'
df.loc[df['Vars'].str.contains('HHA'), 'Encoding'] = 'HHA'
df.loc[df['Vars'].str.contains('HHA') == False, 'Encoding'] = 'Depth'
df.loc[df['Vars'].str.contains('prePT') | (df['Vars'].str.contains('PT') == False), 'Transformation'] = 'None'
df.loc[(df['Vars'].str.contains('prePT') == False) & df['Vars'].str.contains('PT'), 'Transformation'] = 'PT'
df.loc[df['Vars'].str.contains('Sim'), 'Simulated_Data'] = 'Sim'
df.loc[df['Vars'].str.contains('Sim') == False, 'Simulated_Data'] = 'None'

del df['Vars']

# %%
df.sample(5)
# Out:
#       TP   FP  FN    TN  Specificity  Sensitivity  Precision  Accuracy  \
# 82   253   32  49  2495     0.987337     0.837748   0.887719  0.971368
# 81   272   57  44  2499     0.977700     0.860759   0.826748  0.964833
# 189  185   28  59  2820     0.990169     0.758197   0.868545  0.971863
# 262  235  108  67  2419     0.957262     0.778146   0.685131  0.938141
# 256  229   43  87  2513     0.983177     0.724684   0.841912  0.954735
#
#            F1       MCC model_size Encoding Transformation Simulated_Data
# 82   0.862010  0.846494       Base    Depth             PT           None
# 81   0.843411  0.823824       Base    Depth             PT           None
# 189  0.809628  0.796651       Base    Depth             PT            Sim
# 262  0.728682  0.695723       Tiny    Depth           None           None
# 256  0.778912  0.756485       Tiny    Depth           None           None

# %% [markdown]
# ## N-Way ANOVA
#
# Where N is the number of independent variables.
#
# We test each combination of the 4 independent variables on each of the 6 dependant variables separately

# %%
metrics = ['Specificity', 'Sensitivity', 'Precision', 'Accuracy', 'F1', 'MCC']
vars = ['model_size', 'Encoding', 'Transformation', 'Simulated_Data']

# Build right half of formula
independantString = ''
for i in range(1, len(vars) + 1):
    combs = list(itertools.combinations(vars, i))
    for comb in combs:
        if independantString != '':
            independantString += ' + '
        independantString_sub = ''
        for var in comb:
            if independantString_sub == '':
                independantString_sub = f'C({var})'
            else:
                independantString_sub += f':C({var})'
        independantString += independantString_sub

for metric in metrics:
    print(f'N-Way ANOVA tests for {metric}:\n')
    model = ols(f'{metric} ~ {independantString}', data=df).fit()

    result = sm.stats.anova_lm(model, type=2)

    print(tabulate(result, headers='keys', tablefmt='rst'), '\n')
# Out:
# N-Way ANOVA tests for Specificity:
#
# =============================================================  ====  ===========  ===========  ===========  ===========
# ..                                                               df       sum_sq      mean_sq            F       PR(>F)
# =============================================================  ====  ===========  ===========  ===========  ===========
# C(model_size)                                                     1  0.00182802   0.00182802     4.91697      0.027179
# C(Encoding)                                                       1  0.00219932   0.00219932     5.91568      0.0154628
# C(Transformation)                                                 1  0.00157815   0.00157815     4.24486      0.0400426
# C(Simulated_Data)                                                 1  0.00161818   0.00161818     4.35255      0.037613
# C(model_size):C(Encoding)                                         1  0.000104466  0.000104466    0.28099      0.59636
# C(model_size):C(Transformation)                                   1  6.49833e-06  6.49833e-06    0.0174791    0.894889
# C(model_size):C(Simulated_Data)                                   1  0.00075372   0.00075372     2.02734      0.155303
# C(Encoding):C(Transformation)                                     1  0.000209224  0.000209224    0.562767     0.453607
# C(Encoding):C(Simulated_Data)                                     1  0.000984753  0.000984753    2.64876      0.104451
# C(Transformation):C(Simulated_Data)                               1  9.4329e-06   9.4329e-06     0.0253724    0.873526
# C(model_size):C(Encoding):C(Transformation)                       1  0.00119348   0.00119348     3.21019      0.0739684
# C(model_size):C(Encoding):C(Simulated_Data)                       1  5.21245e-06  5.21245e-06    0.0140203    0.905807
# C(model_size):C(Transformation):C(Simulated_Data)                 1  7.64111e-05  7.64111e-05    0.205529     0.650551
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  0.000163124  0.000163124    0.438767     0.508116
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.00204465   0.00204465     5.49965      0.0195287
# Residual                                                        384  0.142763     0.000371778  nan          nan
# =============================================================  ====  ===========  ===========  ===========  ===========
#
# N-Way ANOVA tests for Sensitivity:
#
# =============================================================  ====  ===========  ===========  ===========  ============
# ..                                                               df       sum_sq      mean_sq            F        PR(>F)
# =============================================================  ====  ===========  ===========  ===========  ============
# C(model_size)                                                     1  0.0899438    0.0899438      9.10509      0.00271888
# C(Encoding)                                                       1  0.0397521    0.0397521      4.02414      0.0455545
# C(Transformation)                                                 1  0.00582597   0.00582597     0.589768     0.442981
# C(Simulated_Data)                                                 1  0.00574126   0.00574126     0.581192     0.446314
# C(model_size):C(Encoding)                                         1  0.0366917    0.0366917      3.71433      0.0546845
# C(model_size):C(Transformation)                                   1  0.00552516   0.00552516     0.559316     0.454994
# C(model_size):C(Simulated_Data)                                   1  0.0015218    0.0015218      0.154053     0.69491
# C(Encoding):C(Transformation)                                     1  0.0972024    0.0972024      9.83988      0.00183937
# C(Encoding):C(Simulated_Data)                                     1  0.00880573   0.00880573     0.891411     0.345689
# C(Transformation):C(Simulated_Data)                               1  0.00176709   0.00176709     0.178884     0.672571
# C(model_size):C(Encoding):C(Transformation)                       1  0.00374615   0.00374615     0.379226     0.538383
# C(model_size):C(Encoding):C(Simulated_Data)                       1  0.00454853   0.00454853     0.460452     0.497822
# C(model_size):C(Transformation):C(Simulated_Data)                 1  0.00164501   0.00164501     0.166525     0.683446
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  0.000970586  0.000970586    0.0982532    0.754106
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.0163743    0.0163743      1.65758      0.198706
# Residual                                                        384  3.79331      0.00987842   nan          nan
# =============================================================  ====  ===========  ===========  ===========  ============
#
# N-Way ANOVA tests for Precision:
#
# =============================================================  ====  ===========  ===========  =============  =============
# ..                                                               df       sum_sq      mean_sq              F         PR(>F)
# =============================================================  ====  ===========  ===========  =============  =============
# C(model_size)                                                     1  0.0845835    0.0845835      8.95644        0.00294362
# C(Encoding)                                                       1  0.154052     0.154052      16.3123         6.48776e-05
# C(Transformation)                                                 1  0.0164223    0.0164223      1.73894        0.188059
# C(Simulated_Data)                                                 1  0.0878856    0.0878856      9.3061         0.00244248
# C(model_size):C(Encoding)                                         1  3.11481e-07  3.11481e-07    3.29824e-05    0.995421
# C(model_size):C(Transformation)                                   1  0.00190374   0.00190374     0.201584       0.653698
# C(model_size):C(Simulated_Data)                                   1  0.0349834    0.0349834      3.70435        0.0550095
# C(Encoding):C(Transformation)                                     1  0.0171252    0.0171252      1.81336        0.1789
# C(Encoding):C(Simulated_Data)                                     1  0.0714306    0.0714306      7.56369        0.0062373
# C(Transformation):C(Simulated_Data)                               1  0.0027979    0.0027979      0.296266       0.586549
# C(model_size):C(Encoding):C(Transformation)                       1  0.0286763    0.0286763      3.0365         0.0822119
# C(model_size):C(Encoding):C(Simulated_Data)                       1  0.00111173   0.00111173     0.11772        0.731708
# C(model_size):C(Transformation):C(Simulated_Data)                 1  0.000460942  0.000460942    0.0488086      0.825267
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  6.58016e-06  6.58016e-06    0.000696765    0.978955
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.0527472    0.0527472      5.58533        0.0186089
# Residual                                                        384  3.62645      0.00944387   nan            nan
# =============================================================  ====  ===========  ===========  =============  =============
#
# N-Way ANOVA tests for Accuracy:
#
# =============================================================  ====  ===========  ===========  =============  =============
# ..                                                               df       sum_sq      mean_sq              F         PR(>F)
# =============================================================  ====  ===========  ===========  =============  =============
# C(model_size)                                                     1  0.00424253   0.00424253    11.0491         0.000972614
# C(Encoding)                                                       1  0.00302668   0.00302668     7.88259        0.00524594
# C(Transformation)                                                 1  0.00119163   0.00119163     3.10343        0.0789232
# C(Simulated_Data)                                                 1  0.00177766   0.00177766     4.62968        0.0320464
# C(model_size):C(Encoding)                                         1  9.6135e-05   9.6135e-05     0.250371       0.617101
# C(model_size):C(Transformation)                                   1  5.89282e-05  5.89282e-05    0.153471       0.695458
# C(model_size):C(Simulated_Data)                                   1  0.000462997  0.000462997    1.20582        0.272851
# C(Encoding):C(Transformation)                                     1  0.00187458   0.00187458     4.88208        0.0277263
# C(Encoding):C(Simulated_Data)                                     1  0.000406819  0.000406819    1.05951        0.303976
# C(Transformation):C(Simulated_Data)                               1  2.22009e-07  2.22009e-07    0.000578193    0.980829
# C(model_size):C(Encoding):C(Transformation)                       1  0.000659839  0.000659839    1.71847        0.190674
# C(model_size):C(Encoding):C(Simulated_Data)                       1  4.55392e-05  4.55392e-05    0.118601       0.730745
# C(model_size):C(Transformation):C(Simulated_Data)                 1  0.000135317  0.000135317    0.352415       0.553099
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  0.000215423  0.000215423    0.561041       0.4543
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.0008899    0.0008899      2.31763        0.128738
# Residual                                                        384  0.147445     0.00038397   nan            nan
# =============================================================  ====  ===========  ===========  =============  =============
#
# N-Way ANOVA tests for F1:
#
# =============================================================  ====  ==========  ==========  ==========  =============
# ..                                                               df      sum_sq     mean_sq           F         PR(>F)
# =============================================================  ====  ==========  ==========  ==========  =============
# C(model_size)                                                     1  0.0870449   0.0870449    11.9451      0.000609138
# C(Encoding)                                                       1  0.0844097   0.0844097    11.5835      0.000735463
# C(Transformation)                                                 1  0.00605836  0.00605836    0.831386    0.362444
# C(Simulated_Data)                                                 1  0.056296    0.056296      7.72548     0.00571241
# C(model_size):C(Encoding)                                         1  0.0156588   0.0156588     2.14886     0.143495
# C(model_size):C(Transformation)                                   1  0.00837358  0.00837358    1.1491      0.28441
# C(model_size):C(Simulated_Data)                                   1  0.00359251  0.00359251    0.492998    0.483018
# C(Encoding):C(Transformation)                                     1  0.0713412   0.0713412     9.79013     0.00188852
# C(Encoding):C(Simulated_Data)                                     1  0.0033048   0.0033048     0.453516    0.501075
# C(Transformation):C(Simulated_Data)                               1  0.00130484  0.00130484    0.179063    0.672417
# C(model_size):C(Encoding):C(Transformation)                       1  0.00235767  0.00235767    0.323542    0.569819
# C(model_size):C(Encoding):C(Simulated_Data)                       1  0.00587124  0.00587124    0.805708    0.369955
# C(model_size):C(Transformation):C(Simulated_Data)                 1  0.00341077  0.00341077    0.468059    0.494294
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  0.00367412  0.00367412    0.504198    0.478092
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.00226668  0.00226668    0.311056    0.577358
# Residual                                                        384  2.79823     0.00728706  nan         nan
# =============================================================  ====  ==========  ==========  ==========  =============
#
# N-Way ANOVA tests for MCC:
#
# =============================================================  ====  ===========  ===========  ===========  =============
# ..                                                               df       sum_sq      mean_sq            F         PR(>F)
# =============================================================  ====  ===========  ===========  ===========  =============
# C(model_size)                                                     1  0.106892     0.106892      14.8295       0.000137843
# C(Encoding)                                                       1  0.102389     0.102389      14.2047       0.000189727
# C(Transformation)                                                 1  0.00468756   0.00468756     0.65032      0.420497
# C(Simulated_Data)                                                 1  0.0535048    0.0535048      7.42289      0.00673428
# C(model_size):C(Encoding)                                         1  0.0136518    0.0136518      1.89396      0.169558
# C(model_size):C(Transformation)                                   1  0.00625042   0.00625042     0.86714      0.352333
# C(model_size):C(Simulated_Data)                                   1  0.00577337   0.00577337     0.800958     0.371368
# C(Encoding):C(Transformation)                                     1  0.0710053    0.0710053      9.85079      0.00182877
# C(Encoding):C(Simulated_Data)                                     1  0.00673571   0.00673571     0.934466     0.334313
# C(Transformation):C(Simulated_Data)                               1  0.000187078  0.000187078    0.0259539    0.872098
# C(model_size):C(Encoding):C(Transformation)                       1  0.0037217    0.0037217      0.516323     0.472852
# C(model_size):C(Encoding):C(Simulated_Data)                       1  0.00472574   0.00472574     0.655617     0.418613
# C(model_size):C(Transformation):C(Simulated_Data)                 1  0.00268971   0.00268971     0.373151     0.541653
# C(Encoding):C(Transformation):C(Simulated_Data)                   1  0.00206908   0.00206908     0.287049     0.592428
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)     1  0.00374598   0.00374598     0.519692     0.471412
# Residual                                                        384  2.7679       0.00720808   nan          nan
# =============================================================  ====  ===========  ===========  ===========  =============

# %% [markdown]
# ## Multivariate ANOVA (MANOVA)
#
# We test each of the 4 independent variables separately on each combination of the 6 dependant variables (MANOVA)

# %%
metrics = ['Specificity', 'Sensitivity', 'Precision', 'Accuracy', 'F1', 'MCC']
vars = ['model_size', 'Encoding', 'Transformation', 'Simulated_Data']

for i in range(2, len(metrics) + 1):
    metric_combs = list(itertools.combinations(metrics, i))
    for comb in metric_combs:
        dependantString = ''
        for metric in comb:
            if dependantString != '':
                dependantString += ' + '
            dependantString += metric
        
        for var in vars:
            independantString = f'C({var})'
            maov = MANOVA.from_formula(f'{dependantString} ~ {independantString}', data=df)
            print(f'MANOVAs for {dependantString}:')
            result = maov.mv_test().summary_frame
            result.drop('Pillai\'s trace', level=1, axis=0, inplace=True)
            result.drop('Hotelling-Lawley trace', level=1, axis=0, inplace=True)
            result.drop('Roy\'s greatest root', level=1, axis=0, inplace=True)
            result = result.reset_index(level=[1])
            del result['Statistic']
            # result = result.iloc[:,0]
            # print(result)
            print(tabulate(result, headers='keys', tablefmt='rst'), '\n')
            # print(maov.mv_test(), '\n')
# Out:
# MANOVAs for Specificity + Sensitivity:
# =============  ===========  ========  ========  ============  ===========
# Effect               Value    Num DF    Den DF       F Value       Pr > F
# =============  ===========  ========  ========  ============  ===========
# Intercept      0.000726545         2       397  273012        0
# C(model_size)  0.962463            2       397       7.74174  0.000503167
# =============  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Sensitivity:
# ===========  =========  ========  ========  ============  ==========
# Effect           Value    Num DF    Den DF       F Value      Pr > F
# ===========  =========  ========  ========  ============  ==========
# Intercept    0.0007356         2       397  269649        0
# C(Encoding)  0.973347          2       397       5.43547  0.00468973
# ===========  =========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000743592         2       397  266749         0
# C(Transformation)  0.989132            2       397       2.18108   0.11427
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Sensitivity:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          0.000734683         2       397  269986       0
# C(Simulated_Data)  0.987224            2       397       2.5689  0.0778929
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Specificity + Precision:
# =============  ===========  ========  ========  ============  =========
# Effect               Value    Num DF    Den DF       F Value     Pr > F
# =============  ===========  ========  ========  ============  =========
# Intercept      0.000200158         2       397  991518        0
# C(model_size)  0.977483            2       397       4.57256  0.0108815
# =============  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Precision:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000197172         2       397   1.00654e+06  0
# C(Encoding)  0.94653             2       397  11.2134       1.83085e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Precision:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          0.000198347         2       397  1.00057e+06   0
# C(Transformation)  0.985365            2       397  2.94826       0.05358
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Precision:
# =================  ===========  ========  ========  ============  ==========
# Effect                   Value    Num DF    Den DF       F Value      Pr > F
# =================  ===========  ========  ========  ============  ==========
# Intercept          0.000199853         2       397  993032        0
# C(Simulated_Data)  0.974254            2       397       5.24557  0.00564233
# =================  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Accuracy:
# =============  ===========  ========  ========  ============  =========
# Effect               Value    Num DF    Den DF       F Value     Pr > F
# =============  ===========  ========  ========  ============  =========
# Intercept      0.000765333         2       397  259166        0
# C(model_size)  0.967464            2       397       6.67566  0.0014076
# =============  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Accuracy:
# ===========  ===========  ========  ========  ============  =========
# Effect             Value    Num DF    Den DF       F Value     Pr > F
# ===========  ===========  ========  ========  ============  =========
# Intercept    0.000773762         2       397  256340        0
# C(Encoding)  0.981331            2       397       3.77621  0.0237364
# ===========  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000778185         2       397  254882        0
# C(Transformation)  0.989757            2       397       2.05418  0.129559
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000770769         2       397  257337        0
# C(Simulated_Data)  0.988701            2       397       2.26852  0.104805
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + F1:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000682827         2       397  290505        0
# C(model_size)  0.971862            2       397       5.74715  0.00346332
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + F1:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000684757         2       397  289685        0
# C(Encoding)  0.971852            2       397       5.74912  0.00345671
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + F1:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000681956         2       397  290876         0
# C(Transformation)  0.989712            2       397       2.06349   0.12837
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + F1:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000682126         2       397  290803        0
# C(Simulated_Data)  0.980843            2       397       3.87693  0.0215031
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + MCC:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000634735         2       397  312530        0
# C(model_size)  0.966128            2       397       6.95938  0.00106993
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + MCC:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000635716         2       397  312048        0
# C(Encoding)  0.967346            2       397       6.70055  0.00137413
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + MCC:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000631658         2       397  314054         0
# C(Transformation)  0.989141            2       397       2.17914   0.11449
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + MCC:
# =================  ===========  ========  ========  ==========  =========
# Effect                   Value    Num DF    Den DF     F Value     Pr > F
# =================  ===========  ========  ========  ==========  =========
# Intercept          0.000633071         2       397  313352      0
# C(Simulated_Data)  0.982119            2       397       3.614  0.0278342
# =================  ===========  ========  ========  ==========  =========
#
# MANOVAs for Sensitivity + Precision:
# =============  =========  ========  ========  ==========  ==========
# Effect             Value    Num DF    Den DF     F Value      Pr > F
# =============  =========  ========  ========  ==========  ==========
# Intercept      0.0140903         2       397  13889.2     0
# C(model_size)  0.95961           2       397      8.3548  0.00027915
# =============  =========  ========  ========  ==========  ==========
#
# MANOVAs for Sensitivity + Precision:
# ===========  ========  ========  ========  ===========  ===========
# Effect          Value    Num DF    Den DF      F Value       Pr > F
# ===========  ========  ========  ========  ===========  ===========
# Intercept    0.015099         2       397  12948.1      0
# C(Encoding)  0.955004         2       397      9.35246  0.000107414
# ===========  ========  ========  ========  ===========  ===========
#
# MANOVAs for Sensitivity + Precision:
# =================  =========  ========  ========  ===========  ========
# Effect                 Value    Num DF    Den DF      F Value    Pr > F
# =================  =========  ========  ========  ===========  ========
# Intercept          0.0152315         2       397  12833.7      0
# C(Transformation)  0.994446          2       397      1.10867  0.331015
# =================  =========  ========  ========  ===========  ========
#
# MANOVAs for Sensitivity + Precision:
# =================  =========  ========  ========  ===========  =========
# Effect                 Value    Num DF    Den DF      F Value     Pr > F
# =================  =========  ========  ========  ===========  =========
# Intercept          0.0146158         2       397  13382.7      0
# C(Simulated_Data)  0.978001          2       397      4.46494  0.0120889
# =================  =========  ========  ========  ===========  =========
#
# MANOVAs for Sensitivity + Accuracy:
# =============  ===========  ========  ========  ============  ===========
# Effect               Value    Num DF    Den DF       F Value       Pr > F
# =============  ===========  ========  ========  ============  ===========
# Intercept      0.000823375         2       397  240883        0
# C(model_size)  0.962911            2       397       7.64582  0.000551845
# =============  ===========  ========  ========  ============  ===========
#
# MANOVAs for Sensitivity + Accuracy:
# ===========  ===========  ========  ========  ============  =========
# Effect             Value    Num DF    Den DF       F Value     Pr > F
# ===========  ===========  ========  ========  ============  =========
# Intercept    0.000837432         2       397  236836        0
# C(Encoding)  0.977694            2       397       4.52884  0.0113567
# ===========  ===========  ========  ========  ============  =========
#
# MANOVAs for Sensitivity + Accuracy:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000842626         2       397  235374        0
# C(Transformation)  0.988329            2       397       2.34412  0.0972585
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Sensitivity + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000834338         2       397  237715        0
# C(Simulated_Data)  0.989017            2       397       2.20438  0.111667
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Sensitivity + F1:
# =============  =========  ========  ========  ==========  ==========
# Effect             Value    Num DF    Den DF     F Value      Pr > F
# =============  =========  ========  ========  ==========  ==========
# Intercept      0.0204089         2       397  9527.67     0
# C(model_size)  0.971143          2       397     5.89841  0.00299004
# =============  =========  ========  ========  ==========  ==========
#
# MANOVAs for Sensitivity + F1:
# ===========  =========  ========  ========  ==========  ==========
# Effect           Value    Num DF    Den DF     F Value      Pr > F
# ===========  =========  ========  ========  ==========  ==========
# Intercept    0.0219282         2       397  8853.76     0
# C(Encoding)  0.971895          2       397     5.74014  0.00348701
# ===========  =========  ========  ========  ==========  ==========
#
# MANOVAs for Sensitivity + F1:
# =================  =========  ========  ========  ==========  =========
# Effect                 Value    Num DF    Den DF     F Value     Pr > F
# =================  =========  ========  ========  ==========  =========
# Intercept          0.0218406         2       397  8890.07     0
# C(Transformation)  0.986776          2       397     2.66024  0.0711782
# =================  =========  ========  ========  ==========  =========
#
# MANOVAs for Sensitivity + F1:
# =================  =========  ========  ========  ==========  ==========
# Effect                 Value    Num DF    Den DF     F Value      Pr > F
# =================  =========  ========  ========  ==========  ==========
# Intercept          0.0209458         2       397  9278.34     0
# C(Simulated_Data)  0.973195          2       397     5.46725  0.00454688
# =================  =========  ========  ========  ==========  ==========
#
# MANOVAs for Sensitivity + MCC:
# =============  =========  ========  ========  ==========  ===========
# Effect             Value    Num DF    Den DF     F Value       Pr > F
# =============  =========  ========  ========  ==========  ===========
# Intercept      0.0202947         2       397  9582.36     0
# C(model_size)  0.965496          2       397     7.09381  0.000939659
# =============  =========  ========  ========  ==========  ===========
#
# MANOVAs for Sensitivity + MCC:
# ===========  ========  ========  ========  ==========  ==========
# Effect          Value    Num DF    Den DF     F Value      Pr > F
# ===========  ========  ========  ========  ==========  ==========
# Intercept    0.021967         2       397  8837.79     0
# C(Encoding)  0.965879         2       397     7.01238  0.00101653
# ===========  ========  ========  ========  ==========  ==========
#
# MANOVAs for Sensitivity + MCC:
# =================  =========  ========  ========  ==========  ========
# Effect                 Value    Num DF    Den DF     F Value    Pr > F
# =================  =========  ========  ========  ==========  ========
# Intercept          0.0218719         2       397  8877.06     0
# C(Transformation)  0.990108          2       397     1.98317  0.138994
# =================  =========  ========  ========  ==========  ========
#
# MANOVAs for Sensitivity + MCC:
# =================  =========  ========  ========  ==========  =========
# Effect                 Value    Num DF    Den DF     F Value     Pr > F
# =================  =========  ========  ========  ==========  =========
# Intercept          0.0210711         2       397  9221.98     0
# C(Simulated_Data)  0.977078          2       397     4.65667  0.0100228
# =================  =========  ========  ========  ==========  =========
#
# MANOVAs for Precision + Accuracy:
# =============  ===========  ========  ========  ===========  ==========
# Effect               Value    Num DF    Den DF      F Value      Pr > F
# =============  ===========  ========  ========  ===========  ==========
# Intercept      0.000336046         2       397  590494       0
# C(model_size)  0.973766            2       397       5.3478  0.00510756
# =============  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Precision + Accuracy:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    0.000339364         2       397  584719       0
# C(Encoding)  0.960966            2       397       8.0629  0.000369468
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Precision + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000338882         2       397  585551        0
# C(Transformation)  0.992362            2       397       1.52784  0.218277
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Precision + Accuracy:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000339886         2       397  583821        0
# C(Simulated_Data)  0.977921            2       397       4.48155  0.0118942
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Precision + F1:
# =============  =========  ========  ========  ==========  ==========
# Effect             Value    Num DF    Den DF     F Value      Pr > F
# =============  =========  ========  ========  ==========  ==========
# Intercept      0.0191374         2       397  10173.9     0
# C(model_size)  0.970437          2       397      6.0471  0.00258812
# =============  =========  ========  ========  ==========  ==========
#
# MANOVAs for Precision + F1:
# ===========  =========  ========  ========  ==========  ===========
# Effect           Value    Num DF    Den DF     F Value       Pr > F
# ===========  =========  ========  ========  ==========  ===========
# Intercept    0.0204376         2       397  9514.01     0
# C(Encoding)  0.960634          2       397     8.13429  0.000344974
# ===========  =========  ========  ========  ==========  ===========
#
# MANOVAs for Precision + F1:
# =================  =========  ========  ========  ===========  ========
# Effect                 Value    Num DF    Den DF      F Value    Pr > F
# =================  =========  ========  ========  ===========  ========
# Intercept          0.0205557         2       397  9458.18      0
# C(Transformation)  0.996058          2       397     0.785553  0.456575
# =================  =========  ========  ========  ===========  ========
#
# MANOVAs for Precision + F1:
# =================  =========  ========  ========  ===========  ==========
# Effect                 Value    Num DF    Den DF      F Value      Pr > F
# =================  =========  ========  ========  ===========  ==========
# Intercept          0.0193508         2       397  10059.5      0
# C(Simulated_Data)  0.976359          2       397      4.80632  0.00865986
# =================  =========  ========  ========  ===========  ==========
#
# MANOVAs for Precision + MCC:
# =============  =========  ========  ========  ==========  ==========
# Effect             Value    Num DF    Den DF     F Value      Pr > F
# =============  =========  ========  ========  ==========  ==========
# Intercept      0.0200768         2       397  9688.51     0
# C(model_size)  0.965941          2       397     6.99903  0.00102973
# =============  =========  ========  ========  ==========  ==========
#
# MANOVAs for Precision + MCC:
# ===========  =========  ========  ========  ==========  ===========
# Effect           Value    Num DF    Den DF     F Value       Pr > F
# ===========  =========  ========  ========  ==========  ===========
# Intercept    0.0215706         2       397  9003.84     0
# C(Encoding)  0.959531          2       397     8.37186  0.000274619
# ===========  =========  ========  ========  ==========  ===========
#
# MANOVAs for Precision + MCC:
# =================  =========  ========  ========  ===========  ========
# Effect                 Value    Num DF    Den DF      F Value    Pr > F
# =================  =========  ========  ========  ===========  ========
# Intercept          0.0216961         2       397  8950.62      0
# C(Transformation)  0.995979          2       397     0.801324  0.449459
# =================  =========  ========  ========  ===========  ========
#
# MANOVAs for Precision + MCC:
# =================  =========  ========  ========  ==========  =========
# Effect                 Value    Num DF    Den DF     F Value     Pr > F
# =================  =========  ========  ========  ==========  =========
# Intercept          0.0204681         2       397  9499.53     0
# C(Simulated_Data)  0.977608          2       397     4.54663  0.0111608
# =================  =========  ========  ========  ==========  =========
#
# MANOVAs for Accuracy + F1:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000436875         2       397  454164        0
# C(model_size)  0.969984            2       397       6.14262  0.00235906
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Accuracy + F1:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000440081         2       397  450855        0
# C(Encoding)  0.973103            2       397       5.48658  0.00446217
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Accuracy + F1:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000437838         2       397  453165        0
# C(Transformation)  0.991126            2       397       1.77735  0.170429
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Accuracy + F1:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000439805         2       397  451138        0
# C(Simulated_Data)  0.982142            2       397       3.60922  0.0279651
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Accuracy + MCC:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000361814         2       397  548427        0
# C(model_size)  0.96593             2       397       7.00138  0.00102739
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Accuracy + MCC:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000362659         2       397  547148        0
# C(Encoding)  0.966901            2       397       6.79516  0.00125397
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Accuracy + MCC:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000359954         2       397  551260        0
# C(Transformation)  0.989053            2       397       2.19713  0.112471
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Accuracy + MCC:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000362584         2       397  547262        0
# C(Simulated_Data)  0.982987            2       397       3.43557  0.0331677
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for F1 + MCC:
# =============  =========  ========  ========  =========  ===========
# Effect             Value    Num DF    Den DF    F Value       Pr > F
# =============  =========  ========  ========  =========  ===========
# Intercept      0.0210504         2       397  9231.26    0
# C(model_size)  0.94956           2       397    10.5443  3.45278e-05
# =============  =========  ========  ========  =========  ===========
#
# MANOVAs for F1 + MCC:
# ===========  =========  ========  ========  ==========  ===========
# Effect           Value    Num DF    Den DF     F Value       Pr > F
# ===========  =========  ========  ========  ==========  ===========
# Intercept    0.0225332         2       397  8610.73     0
# C(Encoding)  0.953608          2       397     9.65689  8.03319e-05
# ===========  =========  ========  ========  ==========  ===========
#
# MANOVAs for F1 + MCC:
# =================  =========  ========  ========  ===========  ========
# Effect                 Value    Num DF    Den DF      F Value    Pr > F
# =================  =========  ========  ========  ===========  ========
# Intercept          0.0225066         2       397  8621.14      0
# C(Transformation)  0.996576          2       397     0.682026  0.506183
# =================  =========  ========  ========  ===========  ========
#
# MANOVAs for F1 + MCC:
# =================  =========  ========  ========  ==========  =========
# Effect                 Value    Num DF    Den DF     F Value     Pr > F
# =================  =========  ========  ========  ==========  =========
# Intercept          0.0213392         2       397  9103.65     0
# C(Simulated_Data)  0.981813          2       397     3.67689  0.0261671
# =================  =========  ========  ========  ==========  =========
#
# MANOVAs for Specificity + Sensitivity + Precision:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000166489         3       396  792713        0
# C(model_size)  0.959609            3       396       5.55609  0.00096231
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000165188         3       396  798957        0
# C(Encoding)  0.944155            3       396       7.80748  4.47831e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          0.000165368         3       396  798087       0
# C(Transformation)  0.985341            3       396       1.9638  0.118863
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Sensitivity + Precision:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000166399         3       396  793140        0
# C(Simulated_Data)  0.97419             3       396       3.49714  0.0156844
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Sensitivity + Accuracy:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000708212         3       396  186253        0
# C(model_size)  0.962426            3       396       5.15342  0.00166505
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity + Accuracy:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000714552         3       396  184599        0
# C(Encoding)  0.96906             3       396       4.21449  0.00595851
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000724622         3       396  182032        0
# C(Transformation)  0.988284            3       396       1.56483  0.197388
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Sensitivity + Accuracy:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          0.000714876         3       396  184515       0
# C(Simulated_Data)  0.986484            3       396       1.8086  0.145009
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Sensitivity + F1:
# =============  ===========  ========  ========  ===========  ==========
# Effect               Value    Num DF    Den DF      F Value      Pr > F
# =============  ===========  ========  ========  ===========  ==========
# Intercept      0.000112451         3       396  1.17371e+06  0
# C(model_size)  0.953478            3       396  6.44054      0.00028827
# =============  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + F1:
# ===========  ==========  ========  ========  =========  =========
# Effect            Value    Num DF    Den DF    F Value     Pr > F
# ===========  ==========  ========  ========  =========  =========
# Intercept    0.00011517         3       396  1.146e+06  0
# C(Encoding)  0.971808           3       396  3.82935    0.0100281
# ===========  ==========  ========  ========  =========  =========
#
# MANOVAs for Specificity + Sensitivity + F1:
# =================  ==========  ========  ========  ===========  ========
# Effect                  Value    Num DF    Den DF      F Value    Pr > F
# =================  ==========  ========  ========  ===========  ========
# Intercept          0.00011515         3       396  1.14619e+06  0
# C(Transformation)  0.986618           3       396  1.79036      0.148418
# =================  ==========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Sensitivity + F1:
# =================  ===========  ========  ========  ===========  ===========
# Effect                   Value    Num DF    Den DF      F Value       Pr > F
# =================  ===========  ========  ========  ===========  ===========
# Intercept          0.000113907         3       396  1.15871e+06  0
# C(Simulated_Data)  0.958772            3       396  5.67618      0.000817072
# =================  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + MCC:
# =============  ===========  ========  ========  ===========  ==========
# Effect               Value    Num DF    Den DF      F Value      Pr > F
# =============  ===========  ========  ========  ===========  ==========
# Intercept      7.99804e-05         3       396  1.65027e+06  0
# C(model_size)  0.961864            3       396  5.23349      0.00149315
# =============  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + MCC:
# ===========  ===========  ========  ========  ===========  ==========
# Effect             Value    Num DF    Den DF      F Value      Pr > F
# ===========  ===========  ========  ========  ===========  ==========
# Intercept    8.01697e-05         3       396  1.64638e+06  0
# C(Encoding)  0.961675            3       396  5.26051      0.00143921
# ===========  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + MCC:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          8.04264e-05         3       396  1.64112e+06  0
# C(Transformation)  0.989123            3       396  1.45149      0.227377
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Sensitivity + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          7.96433e-05         3       396  1.65726e+06  0
# C(Simulated_Data)  0.964135            3       396  4.91035      0.00231752
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Precision + Accuracy:
# =============  =========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# =============  =========  ========  ========  ============  ==========
# Intercept      0.0001899         3       396  694972        0
# C(model_size)  0.961094          3       396       5.34345  0.00128554
# =============  =========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Precision + Accuracy:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000187432         3       396  704123        0
# C(Encoding)  0.945429            3       396       7.61922  5.78607e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Precision + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000188136         3       396  701487        0
# C(Transformation)  0.985361            3       396       1.96106  0.119283
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Precision + Accuracy:
# =================  ==========  ========  ========  ============  =========
# Effect                  Value    Num DF    Den DF       F Value     Pr > F
# =================  ==========  ========  ========  ============  =========
# Intercept          0.00018954         3       396  696292        0
# C(Simulated_Data)  0.974183           3       396       3.49812  0.0156638
# =================  ==========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Precision + F1:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000189942         3       396  694815        0
# C(model_size)  0.969475            3       396       4.15614  0.00644818
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Precision + F1:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000187418         3       396  704174        0
# C(Encoding)  0.945772            3       396       7.56857  6.19906e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Precision + F1:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000188003         3       396  701983        0
# C(Transformation)  0.984855            3       396       2.02992  0.109154
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Precision + F1:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000189692         3       396  695733        0
# C(Simulated_Data)  0.972693            3       396       3.70566  0.0118476
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Precision + MCC:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000189019         3       396  698209        0
# C(model_size)  0.965295            3       396       4.74582  0.00289823
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Precision + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    0.000186612         3       396  707217       0
# C(Encoding)  0.945249            3       396       7.6458  5.58045e-05
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Precision + MCC:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000187192         3       396  705025        0
# C(Transformation)  0.98525             3       396       1.97611  0.116994
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Precision + MCC:
# =================  ==========  ========  ========  ============  =========
# Effect                  Value    Num DF    Den DF       F Value     Pr > F
# =================  ==========  ========  ========  ============  =========
# Intercept          0.00018872         3       396  699316        0
# C(Simulated_Data)  0.973673           3       396       3.56917  0.0142371
# =================  ==========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Accuracy + F1:
# =============  ===========  ========  ========  ============  =========
# Effect               Value    Num DF    Den DF       F Value     Pr > F
# =============  ===========  ========  ========  ============  =========
# Intercept      0.000405266         3       396  325580        0
# C(model_size)  0.967225            3       396       4.47288  0.0041981
# =============  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Accuracy + F1:
# ===========  ===========  ========  ========  ============  ==========
# Effect             Value    Num DF    Den DF       F Value      Pr > F
# ===========  ===========  ========  ========  ============  ==========
# Intercept    0.000409235         3       396  322421        0
# C(Encoding)  0.968862            3       396       4.24234  0.00573795
# ===========  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Accuracy + F1:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          0.000407693         3       396  323641       0
# C(Transformation)  0.989712            3       396       1.3722  0.250814
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Accuracy + F1:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000409221         3       396  322432        0
# C(Simulated_Data)  0.973666            3       396       3.57003  0.0142205
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Accuracy + MCC:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000325734         3       396  405107        0
# C(model_size)  0.964898            3       396       4.80206  0.00268501
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Accuracy + MCC:
# ===========  ==========  ========  ========  ============  ===========
# Effect            Value    Num DF    Den DF       F Value       Pr > F
# ===========  ==========  ========  ========  ============  ===========
# Intercept    0.00032625         3       396  404465        0
# C(Encoding)  0.959651           3       396       5.54994  0.000970406
# ===========  ==========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Accuracy + MCC:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000324936         3       396  406102        0
# C(Transformation)  0.988588            3       396       1.52371  0.207815
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Accuracy + MCC:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000326853         3       396  403720        0
# C(Simulated_Data)  0.975788            3       396       3.27528  0.0211204
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + F1 + MCC:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000436938         3       396  301970        0
# C(model_size)  0.942347            3       396       8.07574  3.1092e-05
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + F1 + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    0.000436754         3       396  302098       0
# C(Encoding)  0.950122            3       396       6.9296  0.000148015
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + F1 + MCC:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000430083         3       396  306785        0
# C(Transformation)  0.97592             3       396       3.25694  0.0216456
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + F1 + MCC:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          0.000434242         3       396  303846       0
# C(Simulated_Data)  0.978339            3       396       2.9225  0.0338201
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Sensitivity + Precision + Accuracy:
# =============  ==========  ========  ========  ============  ========
# Effect              Value    Num DF    Den DF       F Value    Pr > F
# =============  ==========  ========  ========  ============  ========
# Intercept      0.00028568         3       396  461923        0
# C(model_size)  0.959505           3       396       5.57097  0.000943
# =============  ==========  ========  ========  ============  ========
#
# MANOVAs for Sensitivity + Precision + Accuracy:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000284159         3       396  464397        0
# C(Encoding)  0.944385            3       396       7.77343  4.69066e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Sensitivity + Precision + Accuracy:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000284496         3       396  463846         0
# C(Transformation)  0.986031            3       396       1.86998   0.13407
# ...
#
# MANOVAs for Precision + Accuracy + F1 + MCC:
# =============  ===========  ========  ========  ============  ===========
# Effect               Value    Num DF    Den DF       F Value       Pr > F
# =============  ===========  ========  ========  ============  ===========
# Intercept      0.000218896         4       395  451028        0
# C(model_size)  0.938602            4       395       6.45963  4.82227e-05
# =============  ===========  ========  ========  ============  ===========
#
# MANOVAs for Precision + Accuracy + F1 + MCC:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000215886         4       395  457319        0
# C(Encoding)  0.93892             4       395       6.42407  5.13061e-05
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000216513         4       395  455994        0
# C(Transformation)  0.973422            4       395       2.69627  0.0305687
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          0.000218811         4       395  451203       0
# C(Simulated_Data)  0.961206            4       395       3.9855  0.00349848
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1:
# =============  ===========  ========  ========  ============  ==========
# Effect               Value    Num DF    Den DF       F Value      Pr > F
# =============  ===========  ========  ========  ============  ==========
# Intercept      0.000101975         5       394  772663        0
# C(model_size)  0.934224            5       394       5.54807  5.9426e-05
# =============  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000103194         5       394  763534        0
# C(Encoding)  0.937807            5       394       5.22582  0.000116883
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1:
# =================  ===========  ========  ========  ============  =========
# Effect                   Value    Num DF    Den DF       F Value     Pr > F
# =================  ===========  ========  ========  ============  =========
# Intercept          0.000103252         5       394  763102        0
# C(Transformation)  0.973622            5       394       2.13492  0.0605461
# =================  ===========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1:
# =================  ===========  ========  ========  ============  ==========
# Effect                   Value    Num DF    Den DF       F Value      Pr > F
# =================  ===========  ========  ========  ============  ==========
# Intercept          0.000102146         5       394  771363        0
# C(Simulated_Data)  0.958469            5       394       3.41445  0.00494472
# =================  ===========  ========  ========  ============  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + MCC:
# =============  ===========  ========  ========  ===========  ===========
# Effect               Value    Num DF    Den DF      F Value       Pr > F
# =============  ===========  ========  ========  ===========  ===========
# Intercept      6.68855e-05         5       394  1.17805e+06  0
# C(model_size)  0.933506            5       394  5.61294      5.18513e-05
# =============  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    6.81796e-05         5       394  1.15569e+06  0
# C(Encoding)  0.937499            5       394  5.25343      0.000110308
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + MCC:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          6.81419e-05         5       394  1.15633e+06  0
# C(Transformation)  0.974375            5       394  2.07231      0.0680277
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          6.73495e-05         5       394  1.16994e+06  0
# C(Simulated_Data)  0.961508            5       394  3.1546       0.00834281
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision + F1 + MCC:
# =============  ===========  ========  ========  ===========  ===========
# Effect               Value    Num DF    Den DF      F Value       Pr > F
# =============  ===========  ========  ========  ===========  ===========
# Intercept      4.38446e-05         5       394  1.79718e+06  0
# C(model_size)  0.934675            5       394  5.50734      6.47373e-05
# =============  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + F1 + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    4.40349e-05         5       394  1.78941e+06  0
# C(Encoding)  0.937546            5       394  5.2492       0.000111291
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + F1 + MCC:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          4.40345e-05         5       394  1.78943e+06  0
# C(Transformation)  0.973721            5       394  2.1267       0.0614822
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + F1 + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          4.39561e-05         5       394  1.79262e+06  0
# C(Simulated_Data)  0.9574              5       394  3.50629      0.00410515
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + Accuracy + F1 + MCC:
# =============  ===========  ========  ========  ===========  ===========
# Effect               Value    Num DF    Den DF      F Value       Pr > F
# =============  ===========  ========  ========  ===========  ===========
# Intercept      7.77079e-05         5       394  1.01398e+06  0
# C(model_size)  0.935562            5       394  5.42746      7.65634e-05
# =============  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Accuracy + F1 + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    7.75047e-05         5       394  1.01663e+06  0
# C(Encoding)  0.939267            5       394  5.09519      0.000153674
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          7.78185e-05         5       394  1.01253e+06  0
# C(Transformation)  0.973231            5       394  2.1674       0.0569784
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Specificity + Sensitivity + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          7.73302e-05         5       394  1.01893e+06  0
# C(Simulated_Data)  0.958728            5       394  3.39222      0.00517207
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Precision + Accuracy + F1 + MCC:
# =============  ==========  ========  ========  ============  ===========
# Effect              Value    Num DF    Den DF       F Value       Pr > F
# =============  ==========  ========  ========  ============  ===========
# Intercept      0.00018802         5       394  419025        0
# C(model_size)  0.937282           5       394       5.27285  0.000105907
# =============  ==========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Precision + Accuracy + F1 + MCC:
# ===========  ===========  ========  ========  ============  ===========
# Effect             Value    Num DF    Den DF       F Value       Pr > F
# ===========  ===========  ========  ========  ============  ===========
# Intercept    0.000185873         5       394  423866        0
# C(Encoding)  0.938911            5       394       5.12699  0.000143774
# ===========  ===========  ========  ========  ============  ===========
#
# MANOVAs for Specificity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ============  ========
# Effect                   Value    Num DF    Den DF       F Value    Pr > F
# =================  ===========  ========  ========  ============  ========
# Intercept          0.000186492         5       394  422460        0
# C(Transformation)  0.973197            5       394       2.17026  0.056673
# =================  ===========  ========  ========  ============  ========
#
# MANOVAs for Specificity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ============  ==========
# Effect                   Value    Num DF    Den DF       F Value      Pr > F
# =================  ===========  ========  ========  ============  ==========
# Intercept          0.000187586         5       394  419995        0
# C(Simulated_Data)  0.954428            5       394       3.76252  0.00243549
# =================  ===========  ========  ========  ============  ==========
#
# MANOVAs for Sensitivity + Precision + Accuracy + F1 + MCC:
# =============  ===========  ========  ========  ==========  ===========
# Effect               Value    Num DF    Den DF     F Value       Pr > F
# =============  ===========  ========  ========  ==========  ===========
# Intercept      1.47976e-05         5       394  5.3251e+06  0
# C(model_size)  0.933459            5       394  5.61723     5.13858e-05
# =============  ===========  ========  ========  ==========  ===========
#
# MANOVAs for Sensitivity + Precision + Accuracy + F1 + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    1.48731e-05         5       394  5.29807e+06  0
# C(Encoding)  0.937721            5       394  5.23353      0.000115008
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Sensitivity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  =========
# Effect                   Value    Num DF    Den DF      F Value     Pr > F
# =================  ===========  ========  ========  ===========  =========
# Intercept          1.48684e-05         5       394  5.29974e+06  0
# C(Transformation)  0.973333            5       394  2.15895      0.0578872
# =================  ===========  ========  ========  ===========  =========
#
# MANOVAs for Sensitivity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          1.48727e-05         5       394  5.29821e+06  0
# C(Simulated_Data)  0.961068            5       394  3.19211      0.00773868
# =================  ===========  ========  ========  ===========  ==========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1 + MCC:
# =============  ===========  ========  ========  ===========  ===========
# Effect               Value    Num DF    Den DF      F Value       Pr > F
# =============  ===========  ========  ========  ===========  ===========
# Intercept      1.20832e-05         6       393  5.42068e+06  0
# C(model_size)  0.933456            6       393  4.66938      0.000132867
# =============  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1 + MCC:
# ===========  ===========  ========  ========  ===========  ===========
# Effect             Value    Num DF    Den DF      F Value       Pr > F
# ===========  ===========  ========  ========  ===========  ===========
# Intercept    1.21333e-05         6       393  5.39831e+06  0
# C(Encoding)  0.937394            6       393  4.37458      0.000271532
# ===========  ===========  ========  ========  ===========  ===========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  ========
# Effect                   Value    Num DF    Den DF      F Value    Pr > F
# =================  ===========  ========  ========  ===========  ========
# Intercept          1.21292e-05         6       393  5.40011e+06  0
# C(Transformation)  0.973194            6       393  1.80418      0.096993
# =================  ===========  ========  ========  ===========  ========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1 + MCC:
# =================  ===========  ========  ========  ===========  ==========
# Effect                   Value    Num DF    Den DF      F Value      Pr > F
# =================  ===========  ========  ========  ===========  ==========
# Intercept          1.21025e-05         6       393  5.41204e+06  0
# C(Simulated_Data)  0.950211            6       393  3.43205      0.00258027
# =================  ===========  ========  ========  ===========  ==========

# %% [markdown]
# ## N-Way Multivariate ANOVA (N-Way MANOVA)
#
# Where N is the number of independent variables.
#
# We test each combination of the 4 independent variables on each combination of the 6 dependant variables (MANOVA)

# %%
metrics = ['Specificity', 'Sensitivity', 'Precision', 'Accuracy', 'F1', 'MCC']
vars = ['model_size', 'Encoding', 'Transformation', 'Simulated_Data']

# Build right half of formula
independantString = ''
for i in range(1, len(vars) + 1):
    var_combs = list(itertools.combinations(vars, i))
    for comb in var_combs:
        if independantString != '':
            independantString += ' + '
        independantString_sub = ''
        for var in comb:
            if independantString_sub == '':
                independantString_sub = f'C({var})'
            else:
                independantString_sub += f':C({var})'
        independantString += independantString_sub

for i in range(2, len(metrics) + 1):
    metric_combs = list(itertools.combinations(metrics, i))
    for comb in metric_combs:
        dependantString = ''
        for metric in comb:
            if dependantString != '':
                dependantString += ' + '
            dependantString += metric
        maov = MANOVA.from_formula(f'{dependantString} ~ {independantString}', data=df)
        print(f'MANOVAs for {dependantString}:')
        result = maov.mv_test().summary_frame
        result.drop('Pillai\'s trace', level=1, axis=0, inplace=True)
        result.drop('Hotelling-Lawley trace', level=1, axis=0, inplace=True)
        result.drop('Roy\'s greatest root', level=1, axis=0, inplace=True)
        result = result.reset_index(level=[1])
        del result['Statistic']
        # result = result.iloc[:,0]
        # print(result)
        print(tabulate(result, headers='keys', tablefmt='rst'), '\n')
        # print(maov.mv_test(), '\n')
# Out:
# MANOVAs for Specificity + Sensitivity:
# =============================================================  ==========  ========  ========  =============  ========
# Effect                                                              Value    Num DF    Den DF        F Value    Pr > F
# =============================================================  ==========  ========  ========  =============  ========
# Intercept                                                      0.00535939         2       383  35540.2        0
# C(model_size)                                                  0.994931           2       383      0.975567   0.377913
# C(Encoding)                                                    0.999747           2       383      0.0484159  0.952743
# C(Transformation)                                              0.996837           2       383      0.607679   0.545138
# C(Simulated_Data)                                              0.994282           2       383      1.10135    0.333474
# C(model_size):C(Encoding)                                      0.999783           2       383      0.0415465  0.959309
# C(model_size):C(Transformation)                                0.998975           2       383      0.196444   0.82173
# C(model_size):C(Simulated_Data)                                0.99832            2       383      0.322241   0.72472
# C(Encoding):C(Transformation)                                  0.996418           2       383      0.688347   0.503026
# C(Encoding):C(Simulated_Data)                                  0.988349           2       383      2.25741    0.106012
# C(Transformation):C(Simulated_Data)                            0.997297           2       383      0.518941   0.595568
# C(model_size):C(Encoding):C(Transformation)                    0.999131           2       383      0.166647   0.84656
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989981           2       383      1.93809    0.145388
# C(model_size):C(Transformation):C(Simulated_Data)              0.989584           2       383      2.01557    0.134655
# C(Encoding):C(Transformation):C(Simulated_Data)                0.993857           2       383      1.1837     0.307262
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.983474           2       383      3.21797    0.041121
# =============================================================  ==========  ========  ========  =============  ========
#
# MANOVAs for Specificity + Precision:
# =============================================================  ==========  ========  ========  ==============  =========
# Effect                                                              Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ==========  ========  ========  ==============  =========
# Intercept                                                      0.00151835         2       383  125933          0
# C(model_size)                                                  0.999589           2       383       0.0786838  0.924347
# C(Encoding)                                                    0.997852           2       383       0.412295   0.662422
# C(Transformation)                                              0.997778           2       383       0.426461   0.653125
# C(Simulated_Data)                                              0.988806           2       383       2.16788    0.115822
# C(model_size):C(Encoding)                                      0.999513           2       383       0.0932477  0.910989
# C(model_size):C(Transformation)                                0.998947           2       383       0.201874   0.817285
# C(model_size):C(Simulated_Data)                                0.996624           2       383       0.648752   0.523271
# C(Encoding):C(Transformation)                                  0.993234           2       383       1.30448    0.272516
# C(Encoding):C(Simulated_Data)                                  0.981488           2       383       3.61187    0.0279251
# C(Transformation):C(Simulated_Data)                            0.997279           2       383       0.522455   0.593485
# C(model_size):C(Encoding):C(Transformation)                    0.999498           2       383       0.0961587  0.908342
# C(model_size):C(Encoding):C(Simulated_Data)                    0.993585           2       383       1.23647    0.291564
# C(model_size):C(Transformation):C(Simulated_Data)              0.989883           2       383       1.95719    0.142665
# C(Encoding):C(Transformation):C(Simulated_Data)                0.991669           2       383       1.60881    0.201475
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.985054           2       383       2.90568    0.0559189
# =============================================================  ==========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Accuracy:
# =============================================================  ==========  ========  ========  ============  =========
# Effect                                                              Value    Num DF    Den DF       F Value     Pr > F
# =============================================================  ==========  ========  ========  ============  =========
# Intercept                                                      0.00567674         2       383  33542.6       0
# C(model_size)                                                  0.994051           2       383      1.14606   0.318973
# C(Encoding)                                                    0.998837           2       383      0.223007  0.800213
# C(Transformation)                                              0.997173           2       383      0.542832  0.581546
# C(Simulated_Data)                                              0.993832           2       383      1.18846   0.305812
# C(model_size):C(Encoding)                                      0.999345           2       383      0.125427  0.882157
# C(model_size):C(Transformation)                                0.999077           2       383      0.176955  0.837886
# C(model_size):C(Simulated_Data)                                0.998343           2       383      0.317919  0.727854
# C(Encoding):C(Transformation)                                  0.995906           2       383      0.787158  0.455871
# C(Encoding):C(Simulated_Data)                                  0.987417           2       383      2.44026   0.088492
# C(Transformation):C(Simulated_Data)                            0.996907           2       383      0.594168  0.55253
# C(model_size):C(Encoding):C(Transformation)                    0.999097           2       383      0.173015  0.841191
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989518           2       383      2.02862   0.132928
# C(model_size):C(Transformation):C(Simulated_Data)              0.989013           2       383      2.12742   0.12055
# C(Encoding):C(Transformation):C(Simulated_Data)                0.993008           2       383      1.34845   0.260872
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.981908           2       383      3.52837   0.0303105
# =============================================================  ==========  ========  ========  ============  =========
#
# MANOVAs for Specificity + F1:
# =============================================================  ==========  ========  ========  =============  =========
# Effect                                                              Value    Num DF    Den DF        F Value     Pr > F
# =============================================================  ==========  ========  ========  =============  =========
# Intercept                                                      0.00515522         2       383  36955.3        0
# C(model_size)                                                  0.997124           2       383      0.552334   0.576062
# C(Encoding)                                                    0.999591           2       383      0.0782847  0.924716
# C(Transformation)                                              0.997398           2       383      0.499521   0.607216
# C(Simulated_Data)                                              0.994228           2       383      1.11174    0.330047
# C(model_size):C(Encoding)                                      0.99967            2       383      0.0632888  0.938682
# C(model_size):C(Transformation)                                0.998868           2       383      0.217035   0.805001
# C(model_size):C(Simulated_Data)                                0.998088           2       383      0.36694    0.693095
# C(Encoding):C(Transformation)                                  0.99593            2       383      0.782642   0.457926
# C(Encoding):C(Simulated_Data)                                  0.989882           2       383      1.95737    0.14264
# C(Transformation):C(Simulated_Data)                            0.997459           2       383      0.487801   0.614356
# C(model_size):C(Encoding):C(Transformation)                    0.999447           2       383      0.105867   0.899571
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989762           2       383      1.98077    0.139373
# C(model_size):C(Transformation):C(Simulated_Data)              0.98984            2       383      1.9656     0.141482
# C(Encoding):C(Transformation):C(Simulated_Data)                0.994518           2       383      1.05559    0.348997
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.984448           2       383      3.02525    0.0497073
# =============================================================  ==========  ========  ========  =============  =========
#
# MANOVAs for Specificity + MCC:
# =============================================================  =========  ========  ========  =============  =========
# Effect                                                             Value    Num DF    Den DF        F Value     Pr > F
# =============================================================  =========  ========  ========  =============  =========
# Intercept                                                      0.0048073         2       383  39643.7        0
# C(model_size)                                                  0.996336          2       383      0.704322   0.495083
# C(Encoding)                                                    0.999443          2       383      0.106696   0.898825
# C(Transformation)                                              0.996767          2       383      0.621044   0.537923
# C(Simulated_Data)                                              0.994283          2       383      1.10104    0.333574
# C(model_size):C(Encoding)                                      0.999615          2       383      0.0738166  0.928855
# C(model_size):C(Transformation)                                0.998843          2       383      0.221795   0.801182
# C(model_size):C(Simulated_Data)                                0.997802          2       383      0.42189    0.656111
# C(Encoding):C(Transformation)                                  0.994883          2       383      0.984914   0.374415
# C(Encoding):C(Simulated_Data)                                  0.991251          2       383      1.69021    0.185854
# C(Transformation):C(Simulated_Data)                            0.99743           2       383      0.493479   0.610887
# C(model_size):C(Encoding):C(Transformation)                    0.999405          2       383      0.113915   0.892364
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989964          2       383      1.94132    0.144924
# C(model_size):C(Transformation):C(Simulated_Data)              0.989753          2       383      1.98265    0.139114
# C(Encoding):C(Transformation):C(Simulated_Data)                0.995132          2       383      0.936749   0.392796
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.984367          2       383      3.04125    0.0489308
# =============================================================  =========  ========  ========  =============  =========
#
# MANOVAs for Sensitivity + Precision:
# =============================================================  =========  ========  ========  ============  ============
# Effect                                                             Value    Num DF    Den DF       F Value        Pr > F
# =============================================================  =========  ========  ========  ============  ============
# Intercept                                                      0.0923461         2       383  1882.22       7.54533e-199
# C(model_size)                                                  0.995299          2       383     0.904563   0.405582
# C(Encoding)                                                    0.999902          2       383     0.0187079  0.981467
# C(Transformation)                                              0.997064          2       383     0.563902   0.569456
# C(Simulated_Data)                                              0.989567          2       383     2.01902    0.134197
# C(model_size):C(Encoding)                                      0.999732          2       383     0.0512611  0.950037
# C(model_size):C(Transformation)                                0.999231          2       383     0.147435   0.862968
# C(model_size):C(Simulated_Data)                                0.999048          2       383     0.182448   0.8333
# C(Encoding):C(Transformation)                                  0.994598          2       383     1.04014    0.354403
# C(Encoding):C(Simulated_Data)                                  0.978905          2       383     4.12681    0.0168573
# C(Transformation):C(Simulated_Data)                            0.99697           2       383     0.581954   0.559299
# C(model_size):C(Encoding):C(Transformation)                    0.998905          2       383     0.209956   0.810714
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989692          2       383     1.99461    0.137477
# C(model_size):C(Transformation):C(Simulated_Data)              0.990352          2       383     1.86562    0.156204
# C(Encoding):C(Transformation):C(Simulated_Data)                0.989597          2       383     2.01321    0.134971
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.981386          2       383     3.63217    0.0273742
# =============================================================  =========  ========  ========  ============  ============
#
# MANOVAs for Sensitivity + Accuracy:
# =============================================================  ==========  ========  ========  =============  =========
# Effect                                                              Value    Num DF    Den DF        F Value     Pr > F
# =============================================================  ==========  ========  ========  =============  =========
# Intercept                                                      0.00612379         2       383  31080          0
# C(model_size)                                                  0.994546           2       383      1.05022    0.350865
# C(Encoding)                                                    0.999932           2       383      0.0129822  0.987102
# C(Transformation)                                              0.996892           2       383      0.596967   0.55099
# C(Simulated_Data)                                              0.99543            2       383      0.879153   0.415971
# C(model_size):C(Encoding)                                      0.999752           2       383      0.0475608  0.953558
# C(model_size):C(Transformation)                                0.999005           2       383      0.190741   0.826425
# C(model_size):C(Simulated_Data)                                0.998434           2       383      0.300369   0.740719
# C(Encoding):C(Transformation)                                  0.996162           2       383      0.737741   0.478871
# C(Encoding):C(Simulated_Data)                                  0.989547           2       383      2.0229     0.133682
# C(Transformation):C(Simulated_Data)                            0.997932           2       383      0.396926   0.67266
# C(model_size):C(Encoding):C(Transformation)                    0.999197           2       383      0.153859   0.857446
# C(model_size):C(Encoding):C(Simulated_Data)                    0.990958           2       383      1.74739    0.175613
# C(model_size):C(Transformation):C(Simulated_Data)              0.991299           2       383      1.68095    0.187567
# C(Encoding):C(Transformation):C(Simulated_Data)                0.994655           2       383      1.02899    0.358352
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.986073           2       383      2.70474    0.0681657
# =============================================================  ==========  ========  ========  =============  =========
#
# MANOVAs for Sensitivity + F1:
# =============================================================  ========  ========  ========  ============  ============
# Effect                                                            Value    Num DF    Den DF       F Value        Pr > F
# =============================================================  ========  ========  ========  ============  ============
# Intercept                                                      0.130956         2       383  1270.82       8.50246e-170
# C(model_size)                                                  0.995659         2       383     0.834992   0.434666
# C(Encoding)                                                    0.999928         2       383     0.013773   0.986322
# C(Transformation)                                              0.996707         2       383     0.632689   0.531716
# C(Simulated_Data)                                              0.989397         2       383     2.05233    0.129846
# C(model_size):C(Encoding)                                      0.99976          2       383     0.0460294  0.955019
# C(model_size):C(Transformation)                                0.999149         2       383     0.163091   0.849573
# C(model_size):C(Simulated_Data)                                0.998733         2       383     0.242888   0.78448
# C(Encoding):C(Transformation)                                  0.996056         2       383     0.758335   0.469148
# C(Encoding):C(Simulated_Data)                                  0.987359         2       383     2.4518     0.0874893
# C(Transformation):C(Simulated_Data)                            0.996196         2       383     0.731257   0.481975
# C(model_size):C(Encoding):C(Transformation)                    0.99871          2       383     0.24743    0.78093
# C(model_size):C(Encoding):C(Simulated_Data)                    0.991317         2       383     1.67742    0.188224
# C(model_size):C(Transformation):C(Simulated_Data)              0.988552         2       383     2.21766    0.110259
# C(Encoding):C(Transformation):C(Simulated_Data)                0.993519         2       383     1.24929    0.287873
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.982465         2       383     3.41783    0.0337866
# =============================================================  ========  ========  ========  ============  ============
#
# MANOVAs for Sensitivity + MCC:
# =============================================================  ========  ========  ========  ===========  ============
# Effect                                                            Value    Num DF    Den DF      F Value        Pr > F
# =============================================================  ========  ========  ========  ===========  ============
# Intercept                                                      0.130152         2       383  1279.86      2.61343e-170
# C(model_size)                                                  0.995424         2       383     0.880265  0.41551
# C(Encoding)                                                    0.999932         2       383     0.012989  0.987095
# C(Transformation)                                              0.996934         2       383     0.589023  0.555371
# C(Simulated_Data)                                              0.990272         2       383     1.88112   0.153825
# C(model_size):C(Encoding)                                      0.999749         2       383     0.04811   0.953035
# C(model_size):C(Transformation)                                0.999138         2       383     0.165286  0.847711
# C(model_size):C(Simulated_Data)                                0.998863         2       383     0.218024  0.804206
# C(Encoding):C(Transformation)                                  0.995468         2       383     0.871833  0.419013
# C(Encoding):C(Simulated_Data)                                  0.984765         2       383     2.96258   0.0528709
# C(Transformation):C(Simulated_Data)                            0.996747         2       383     0.624888  0.535866
# C(model_size):C(Encoding):C(Transformation)                    0.998838         2       383     0.222785  0.800391
# C(model_size):C(Encoding):C(Simulated_Data)                    0.990775         2       383     1.78297   0.16953
# C(model_size):C(Transformation):C(Simulated_Data)              0.98936          2       383     2.05953   0.128923
# C(Encoding):C(Transformation):C(Simulated_Data)                0.992327         2       383     1.48082   0.228751
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.982452         2       383     3.42049   0.0336986
# =============================================================  ========  ========  ========  ===========  ============
#
# MANOVAs for Precision + Accuracy:
# =============================================================  ==========  ========  ========  =============  ==========
# Effect                                                              Value    Num DF    Den DF        F Value      Pr > F
# =============================================================  ==========  ========  ========  =============  ==========
# Intercept                                                      0.00258329         2       383  73938.8        0
# C(model_size)                                                  0.995919           2       383      0.784748   0.456967
# C(Encoding)                                                    0.999919           2       383      0.0154478  0.984672
# C(Transformation)                                              0.999944           2       383      0.0106998  0.989358
# C(Simulated_Data)                                              0.987602           2       383      2.40404    0.0917147
# C(model_size):C(Encoding)                                      0.999911           2       383      0.017049   0.983096
# C(model_size):C(Transformation)                                0.999884           2       383      0.0222496  0.977997
# C(model_size):C(Simulated_Data)                                0.999577           2       383      0.0810966  0.92212
# C(Encoding):C(Transformation)                                  0.997547           2       383      0.470891   0.624807
# C(Encoding):C(Simulated_Data)                                  0.972804           2       383      5.35363    0.00509159
# C(Transformation):C(Simulated_Data)                            0.997128           2       383      0.551535   0.576522
# C(model_size):C(Encoding):C(Transformation)                    0.999099           2       383      0.172655   0.841493
# C(model_size):C(Encoding):C(Simulated_Data)                    0.993633           2       383      1.22713    0.294283
# C(model_size):C(Transformation):C(Simulated_Data)              0.991373           2       383      1.66645    0.190283
# C(Encoding):C(Transformation):C(Simulated_Data)                0.987164           2       383      2.4901     0.0842427
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.984003           2       383      3.11328    0.0455818
# =============================================================  ==========  ========  ========  =============  ==========
#
# MANOVAs for Precision + F1:
# =============================================================  ========  ========  ========  =============  ===========
# Effect                                                            Value    Num DF    Den DF        F Value       Pr > F
# =============================================================  ========  ========  ========  =============  ===========
# Intercept                                                      0.121854         2       383  1380.05        8.6772e-176
# C(model_size)                                                  0.996946         2       383     0.586716    0.55665
# C(Encoding)                                                    0.999966         2       383     0.00641622  0.993604
# C(Transformation)                                              0.998564         2       383     0.275333    0.75947
# C(Simulated_Data)                                              0.98983          2       383     1.96748     0.14122
# C(model_size):C(Encoding)                                      0.999793         2       383     0.0396734   0.961107
# C(model_size):C(Transformation)                                0.999447         2       383     0.105906    0.899536
# C(model_size):C(Simulated_Data)                                0.999598         2       383     0.0769203   0.925978
# C(Encoding):C(Transformation)                                  0.996049         2       383     0.759569    0.468571
# C(Encoding):C(Simulated_Data)                                  0.973761         2       383     5.16017     0.00614651
# C(Transformation):C(Simulated_Data)                            0.99726          2       383     0.526157    0.591298
# C(model_size):C(Encoding):C(Transformation)                    0.999148         2       383     0.163356    0.849348
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989161         2       383     2.0985      0.124048
# C(model_size):C(Transformation):C(Simulated_Data)              0.991057         2       383     1.72801     0.17902
# C(Encoding):C(Transformation):C(Simulated_Data)                0.987321         2       383     2.45917     0.0868547
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.98201          2       383     3.50824     0.0309157
# =============================================================  ========  ========  ========  =============  ===========
#
# MANOVAs for Precision + MCC:
# =============================================================  ========  ========  ========  =============  ============
# Effect                                                            Value    Num DF    Den DF        F Value        Pr > F
# =============================================================  ========  ========  ========  =============  ============
# Intercept                                                      0.127132         2       383  1314.8         2.91805e-172
# C(model_size)                                                  0.99587          2       383     0.794222    0.452676
# C(Encoding)                                                    0.999954         2       383     0.00889424  0.991145
# C(Transformation)                                              0.99805          2       383     0.37413     0.688139
# C(Simulated_Data)                                              0.989528         2       383     2.02662     0.133191
# C(model_size):C(Encoding)                                      0.999772         2       383     0.0435918   0.957349
# C(model_size):C(Transformation)                                0.99945          2       383     0.1054      0.89999
# C(model_size):C(Simulated_Data)                                0.999483         2       383     0.099093    0.905682
# C(Encoding):C(Transformation)                                  0.995584         2       383     0.849427    0.428464
# C(Encoding):C(Simulated_Data)                                  0.974636         2       383     4.98361     0.00730009
# C(Transformation):C(Simulated_Data)                            0.997105         2       383     0.555906    0.574014
# C(model_size):C(Encoding):C(Transformation)                    0.99902          2       383     0.187764    0.828887
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989019         2       383     2.12612     0.120705
# C(model_size):C(Transformation):C(Simulated_Data)              0.990803         2       383     1.77761     0.170433
# C(Encoding):C(Transformation):C(Simulated_Data)                0.987649         2       383     2.39487     0.0925491
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.981337         2       383     3.64185     0.0271153
# =============================================================  ========  ========  ========  =============  ============
#
# MANOVAs for Accuracy + F1:
# =============================================================  ==========  ========  ========  ==============  ========
# Effect                                                              Value    Num DF    Den DF         F Value    Pr > F
# =============================================================  ==========  ========  ========  ==============  ========
# Intercept                                                      0.00338681         2       383  56351.3         0
# C(model_size)                                                  0.997              2       383      0.576256    0.562485
# C(Encoding)                                                    0.999964           2       383      0.00689613  0.993128
# C(Transformation)                                              0.99825            2       383      0.335702    0.715046
# C(Simulated_Data)                                              0.996777           2       383      0.619179    0.538924
# C(model_size):C(Encoding)                                      0.999791           2       383      0.0400268   0.960768
# C(model_size):C(Transformation)                                0.999042           2       383      0.183543    0.832389
# C(model_size):C(Simulated_Data)                                0.998439           2       383      0.299433    0.741412
# C(Encoding):C(Transformation)                                  0.996177           2       383      0.734841    0.480257
# C(Encoding):C(Simulated_Data)                                  0.994921           2       383      0.97758     0.377157
# C(Transformation):C(Simulated_Data)                            0.998815           2       383      0.227226    0.796848
# C(model_size):C(Encoding):C(Transformation)                    0.999841           2       383      0.0303767   0.970082
# C(model_size):C(Encoding):C(Simulated_Data)                    0.993097           2       383      1.33115     0.265394
# C(model_size):C(Transformation):C(Simulated_Data)              0.993687           2       383      1.21671     0.297346
# C(Encoding):C(Transformation):C(Simulated_Data)                0.997376           2       383      0.503826    0.604614
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.991494           2       383      1.64296     0.194767
# =============================================================  ==========  ========  ========  ==============  ========
#
# MANOVAs for Accuracy + MCC:
# =============================================================  ==========  ========  ========  =============  ========
# Effect                                                              Value    Num DF    Den DF        F Value    Pr > F
# =============================================================  ==========  ========  ========  =============  ========
# Intercept                                                      0.00281179         2       383  67914.6        0
# C(model_size)                                                  0.996644           2       383      0.644916   0.525275
# C(Encoding)                                                    0.99989            2       383      0.0210165  0.979204
# C(Transformation)                                              0.997525           2       383      0.475055   0.622217
# C(Simulated_Data)                                              0.996752           2       383      0.623975   0.536354
# C(model_size):C(Encoding)                                      0.999769           2       383      0.0442687  0.956702
# C(model_size):C(Transformation)                                0.999015           2       383      0.188801   0.828028
# C(model_size):C(Simulated_Data)                                0.997973           2       383      0.388969   0.678022
# C(Encoding):C(Transformation)                                  0.995155           2       383      0.932393   0.394502
# C(Encoding):C(Simulated_Data)                                  0.997137           2       383      0.549858   0.577487
# C(Transformation):C(Simulated_Data)                            0.998783           2       383      0.233353   0.791987
# C(model_size):C(Encoding):C(Transformation)                    0.999823           2       383      0.0339505  0.966622
# C(model_size):C(Encoding):C(Simulated_Data)                    0.99371            2       383      1.21212    0.298704
# C(model_size):C(Transformation):C(Simulated_Data)              0.993533           2       383      1.2464     0.288702
# C(Encoding):C(Transformation):C(Simulated_Data)                0.998401           2       383      0.306679   0.736067
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.991746           2       383      1.59372    0.204513
# =============================================================  ==========  ========  ========  =============  ========
#
# MANOVAs for F1 + MCC:
# =============================================================  ========  ========  ========  =============  ============
# Effect                                                            Value    Num DF    Den DF        F Value        Pr > F
# =============================================================  ========  ========  ========  =============  ============
# Intercept                                                      0.133996         2       383  1237.65        6.88708e-168
# C(model_size)                                                  0.99543          2       383     0.879156    0.415969
# C(Encoding)                                                    0.999676         2       383     0.0621402   0.939761
# C(Transformation)                                              0.998954         2       383     0.200555    0.818363
# C(Simulated_Data)                                              0.996952         2       383     0.585492    0.557329
# C(model_size):C(Encoding)                                      0.999788         2       383     0.0406912   0.96013
# C(model_size):C(Transformation)                                0.999664         2       383     0.0643905   0.937649
# C(model_size):C(Simulated_Data)                                0.999904         2       383     0.0183832   0.981786
# C(Encoding):C(Transformation)                                  0.994422         2       383     1.0742      0.342596
# C(Encoding):C(Simulated_Data)                                  0.980483         2       383     3.81185     0.0229508
# C(Transformation):C(Simulated_Data)                            0.999403         2       383     0.114467    0.891872
# C(model_size):C(Encoding):C(Transformation)                    0.999986         2       383     0.00266523  0.997338
# C(model_size):C(Encoding):C(Simulated_Data)                    0.995104         2       383     0.942166    0.390684
# C(model_size):C(Transformation):C(Simulated_Data)              0.99722          2       383     0.533917    0.58674
# C(Encoding):C(Transformation):C(Simulated_Data)                0.991297         2       383     1.68132     0.187499
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.994853         2       383     0.990798    0.37223
# =============================================================  ========  ========  ========  =============  ============
#
# MANOVAs for Specificity + Sensitivity + Precision:
# =============================================================  ==========  ========  ========  =============  ==========
# Effect                                                              Value    Num DF    Den DF        F Value      Pr > F
# =============================================================  ==========  ========  ========  =============  ==========
# Intercept                                                      0.00127272         3       382  99920.5        0
# C(model_size)                                                  0.99476            3       382      0.670789   0.570394
# C(Encoding)                                                    0.997794           3       382      0.281554   0.838716
# C(Transformation)                                              0.996117           3       382      0.496354   0.685017
# C(Simulated_Data)                                              0.987463           3       382      1.61661    0.185024
# C(model_size):C(Encoding)                                      0.999446           3       382      0.0706143  0.975619
# C(model_size):C(Transformation)                                0.998673           3       382      0.169169   0.917167
# C(model_size):C(Simulated_Data)                                0.996497           3       382      0.447641   0.719109
# C(Encoding):C(Transformation)                                  0.992052           3       382      1.02009    0.383668
# C(Encoding):C(Simulated_Data)                                  0.96979            3       382      3.96661    0.00835402
# C(Transformation):C(Simulated_Data)                            0.996962           3       382      0.388064   0.761665
# C(model_size):C(Encoding):C(Transformation)                    0.99882            3       382      0.150416   0.929394
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989579           3       382      1.34086    0.260732
# C(model_size):C(Transformation):C(Simulated_Data)              0.989469           3       382      1.35519    0.256183
# C(Encoding):C(Transformation):C(Simulated_Data)                0.986246           3       382      1.77579    0.151266
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.981376           3       382      2.41641    0.0660624
# =============================================================  ==========  ========  ========  =============  ==========
#
# MANOVAs for Specificity + Sensitivity + Accuracy:
# =============================================================  ==========  ========  ========  ============  =========
# Effect                                                              Value    Num DF    Den DF       F Value     Pr > F
# =============================================================  ==========  ========  ========  ============  =========
# Intercept                                                      0.00521003         3       382  24312.7       0
# C(model_size)                                                  0.994001           3       382      0.768446  0.51225
# C(Encoding)                                                    0.997066           3       382      0.374755  0.771264
# C(Transformation)                                              0.996794           3       382      0.409585  0.746205
# C(Simulated_Data)                                              0.993485           3       382      0.83507   0.475238
# C(model_size):C(Encoding)                                      0.999101           3       382      0.114598  0.951534
# C(model_size):C(Transformation)                                0.998974           3       382      0.130823  0.94173
# C(model_size):C(Simulated_Data)                                0.998287           3       382      0.21855   0.883514
# C(Encoding):C(Transformation)                                  0.995851           3       382      0.530468  0.66162
# C(Encoding):C(Simulated_Data)                                  0.987363           3       382      1.62975   0.181987
# C(Transformation):C(Simulated_Data)                            0.99666            3       382      0.426662  0.734002
# C(model_size):C(Encoding):C(Transformation)                    0.999078           3       382      0.117453  0.949839
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989436           3       382      1.3595    0.254828
# C(model_size):C(Transformation):C(Simulated_Data)              0.988739           3       382      1.45028   0.227785
# C(Encoding):C(Transformation):C(Simulated_Data)                0.993007           3       382      0.896772  0.442887
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.981764           3       382      2.3652    0.0706439
# =============================================================  ==========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Sensitivity + F1:
# =============================================================  ===========  ========  ========  ==============  =========
# Effect                                                               Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ===========  ========  ========  ==============  =========
# Intercept                                                      0.000876817         3       382  145095          0
# C(model_size)                                                  0.99182             3       382       1.05012    0.370315
# C(Encoding)                                                    0.998934            3       382       0.135925   0.938566
# C(Transformation)                                              0.99666             3       382       0.426668   0.733999
# C(Simulated_Data)                                              0.98585             3       382       1.82768    0.141588
# C(model_size):C(Encoding)                                      0.999572            3       382       0.0544776  0.983238
# C(model_size):C(Transformation)                                0.998849            3       382       0.146726   0.931755
# C(model_size):C(Simulated_Data)                                0.997972            3       382       0.258734   0.855097
# C(Encoding):C(Transformation)                                  0.995896            3       382       0.524772   0.665497
# C(Encoding):C(Simulated_Data)                                  0.98734             3       382       1.63272    0.181308
# C(Transformation):C(Simulated_Data)                            0.995882            3       382       0.526499   0.66432
# C(model_size):C(Encoding):C(Transformation)                    0.998229            3       382       0.22596    0.878328
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989757            3       382       1.31783    0.268203
# C(model_size):C(Transformation):C(Simulated_Data)              0.988531            3       382       1.47733    0.220254
# C(Encoding):C(Transformation):C(Simulated_Data)                0.993515            3       382       0.831154   0.477353
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.982386            3       382       2.2831     0.0786403
# =============================================================  ===========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Sensitivity + MCC:
# =============================================================  ===========  ========  ========  ==============  =========
# Effect                                                               Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ===========  ========  ========  ==============  =========
# Intercept                                                      0.000616808         3       382  206312          0
# C(model_size)                                                  0.993838            3       382       0.789531   0.500303
# C(Encoding)                                                    0.997478            3       382       0.3219     0.80954
# C(Transformation)                                              0.996748            3       382       0.415453   0.742004
# C(Simulated_Data)                                              0.986151            3       382       1.78825    0.148886
# C(model_size):C(Encoding)                                      0.999352            3       382       0.0826279  0.96947
# C(model_size):C(Transformation)                                0.998796            3       382       0.153544   0.927381
# C(model_size):C(Simulated_Data)                                0.996997            3       382       0.383581   0.764896
# C(Encoding):C(Transformation)                                  0.993542            3       382       0.827674   0.47924
# C(Encoding):C(Simulated_Data)                                  0.98129             3       382       2.42787    0.0650773
# C(Transformation):C(Simulated_Data)                            0.996653            3       382       0.427562   0.733361
# C(model_size):C(Encoding):C(Transformation)                    0.998435            3       382       0.199629   0.896616
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989908            3       382       1.29817    0.274732
# C(model_size):C(Transformation):C(Simulated_Data)              0.989233            3       382       1.38588    0.246678
# C(Encoding):C(Transformation):C(Simulated_Data)                0.99127             3       382       1.12137    0.340229
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.982445            3       382       2.27523    0.0794518
# =============================================================  ===========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Precision + Accuracy:
# =============================================================  ==========  ========  ========  ============  =========
# Effect                                                              Value    Num DF    Den DF       F Value     Pr > F
# =============================================================  ==========  ========  ========  ============  =========
# Intercept                                                      0.00144827         3       382  87793.9       0
# C(model_size)                                                  0.994045           3       382      0.762869  0.515447
# C(Encoding)                                                    0.997248           3       382      0.351379  0.788174
# C(Transformation)                                              0.995978           3       382      0.514179  0.672739
# C(Simulated_Data)                                              0.987536           3       382      1.60711   0.187246
# C(model_size):C(Encoding)                                      0.999008           3       382      0.126483  0.944392
# C(model_size):C(Transformation)                                0.998646           3       382      0.172648  0.91486
# C(model_size):C(Simulated_Data)                                0.996294           3       382      0.473661  0.700807
# C(Encoding):C(Transformation)                                  0.990708           3       382      1.19432   0.311681
# C(Encoding):C(Simulated_Data)                                  0.972794           3       382      3.56106   0.0144237
# C(Transformation):C(Simulated_Data)                            0.996612           3       382      0.432846  0.729601
# C(model_size):C(Encoding):C(Transformation)                    0.998913           3       382      0.13862   0.936881
# C(model_size):C(Encoding):C(Simulated_Data)                    0.989413           3       382      1.36249   0.25389
# C(model_size):C(Transformation):C(Simulated_Data)              0.988928           3       382      1.42566   0.234843
# C(Encoding):C(Transformation):C(Simulated_Data)                0.987045           3       382      1.67132   0.172689
# ...
# C(model_size):C(Simulated_Data)                                0.996106           5       380      0.297076  0.914413
# C(Encoding):C(Transformation)                                  0.98977            5       380      0.78553   0.560572
# C(Encoding):C(Simulated_Data)                                  0.965753           5       380      2.69504   0.0207755
# C(Transformation):C(Simulated_Data)                            0.995351           5       380      0.354993  0.878955
# C(model_size):C(Encoding):C(Transformation)                    0.998215           5       380      0.135905  0.983963
# C(model_size):C(Encoding):C(Simulated_Data)                    0.98811            5       380      0.914495  0.471488
# C(model_size):C(Transformation):C(Simulated_Data)              0.987603           5       380      0.95397   0.446017
# C(Encoding):C(Transformation):C(Simulated_Data)                0.98437            5       380      1.20674   0.305261
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.980382           5       380      1.52082   0.182297
# =============================================================  ==========  ========  ========  ============  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + MCC:
# =============================================================  ==========  ========  ========  =============  =========
# Effect                                                              Value    Num DF    Den DF        F Value     Pr > F
# =============================================================  ==========  ========  ========  =============  =========
# Intercept                                                      0.00051996         5       380  146089         0
# C(model_size)                                                  0.990628           5       380       0.71904   0.609456
# C(Encoding)                                                    0.99353            5       380       0.494947  0.780041
# C(Transformation)                                              0.994668           5       380       0.407396  0.843647
# C(Simulated_Data)                                              0.985584           5       380       1.11161   0.353634
# C(model_size):C(Encoding)                                      0.998427           5       380       0.11976   0.987972
# C(model_size):C(Transformation)                                0.998603           5       380       0.106341  0.990848
# C(model_size):C(Simulated_Data)                                0.99613            5       380       0.295258  0.915453
# C(Encoding):C(Transformation)                                  0.989692           5       380       0.791605  0.556194
# C(Encoding):C(Simulated_Data)                                  0.964003           5       380       2.83797   0.0156982
# C(Transformation):C(Simulated_Data)                            0.995682           5       380       0.329558  0.89505
# C(model_size):C(Encoding):C(Transformation)                    0.998183           5       380       0.138347  0.983305
# C(model_size):C(Encoding):C(Simulated_Data)                    0.986844           5       380       1.01316   0.409547
# C(model_size):C(Transformation):C(Simulated_Data)              0.987766           5       380       0.941262  0.454118
# C(Encoding):C(Transformation):C(Simulated_Data)                0.983566           5       380       1.26985   0.276173
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.980417           5       380       1.51804   0.183162
# =============================================================  ==========  ========  ========  =============  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + F1 + MCC:
# =============================================================  ===========  ========  ========  ==============  =========
# Effect                                                               Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ===========  ========  ========  ==============  =========
# Intercept                                                      0.000343686         5       380  221056          0
# C(model_size)                                                  0.989911            5       380       0.774545   0.56853
# C(Encoding)                                                    0.995597            5       380       0.336085   0.890994
# C(Transformation)                                              0.994394            5       380       0.428477   0.828771
# C(Simulated_Data)                                              0.983595            5       380       1.26756    0.27719
# C(model_size):C(Encoding)                                      0.999165            5       380       0.0635208  0.997276
# C(model_size):C(Transformation)                                0.998527            5       380       0.112105   0.989663
# C(model_size):C(Simulated_Data)                                0.996025            5       380       0.303335   0.910795
# C(Encoding):C(Transformation)                                  0.990353            5       380       0.740308   0.593642
# C(Encoding):C(Simulated_Data)                                  0.964943            5       380       2.76109    0.0182573
# C(Transformation):C(Simulated_Data)                            0.994687            5       380       0.405952   0.844653
# C(model_size):C(Encoding):C(Transformation)                    0.998227            5       380       0.135003   0.984203
# C(model_size):C(Encoding):C(Simulated_Data)                    0.98507             5       380       1.1519     0.332469
# C(model_size):C(Transformation):C(Simulated_Data)              0.987351            5       380       0.973649   0.433659
# C(Encoding):C(Transformation):C(Simulated_Data)                0.983578            5       380       1.26889    0.276599
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.977563            5       380       1.74438    0.123543
# =============================================================  ===========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Sensitivity + Accuracy + F1 + MCC:
# =============================================================  ===========  ========  ========  ==============  =========
# Effect                                                               Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ===========  ========  ========  ==============  =========
# Intercept                                                      0.000597136         5       380  127198          0
# C(model_size)                                                  0.990084            5       380       0.76118    0.578278
# C(Encoding)                                                    0.9941              5       380       0.451075   0.812479
# C(Transformation)                                              0.994388            5       380       0.428893   0.828473
# C(Simulated_Data)                                              0.985159            5       380       1.1449     0.336075
# C(model_size):C(Encoding)                                      0.998599            5       380       0.106606   0.990795
# C(model_size):C(Transformation)                                0.99879             5       380       0.0920599  0.993454
# C(model_size):C(Simulated_Data)                                0.996029            5       380       0.302962   0.911012
# C(Encoding):C(Transformation)                                  0.990147            5       380       0.756244   0.581897
# C(Encoding):C(Simulated_Data)                                  0.96985             5       380       2.36261    0.0394629
# C(Transformation):C(Simulated_Data)                            0.995218            5       380       0.36521    0.872283
# C(model_size):C(Encoding):C(Transformation)                    0.998217            5       380       0.13576    0.984002
# C(model_size):C(Encoding):C(Simulated_Data)                    0.988887            5       380       0.854102   0.512147
# C(model_size):C(Transformation):C(Simulated_Data)              0.987523            5       380       0.960196   0.442083
# C(Encoding):C(Transformation):C(Simulated_Data)                0.986131            5       380       1.06885    0.377182
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.980856            5       380       1.48331    0.194276
# =============================================================  ===========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Precision + Accuracy + F1 + MCC:
# =============================================================  ==========  ========  ========  ============  ========
# Effect                                                              Value    Num DF    Den DF       F Value    Pr > F
# =============================================================  ==========  ========  ========  ============  ========
# Intercept                                                      0.00143471         5       380  52896.5       0
# C(model_size)                                                  0.989886           5       380      0.776506  0.567105
# C(Encoding)                                                    0.992999           5       380      0.535806  0.749153
# C(Transformation)                                              0.994365           5       380      0.430651  0.827217
# C(Simulated_Data)                                              0.9829             5       380      1.32218   0.253809
# C(model_size):C(Encoding)                                      0.998112           5       380      0.143767  0.981797
# C(model_size):C(Transformation)                                0.998527           5       380      0.11211   0.989662
# C(model_size):C(Simulated_Data)                                0.996087           5       380      0.29853   0.913578
# C(Encoding):C(Transformation)                                  0.989828           5       380      0.781029  0.563826
# C(Encoding):C(Simulated_Data)                                  0.966567           5       380      2.62878   0.023638
# C(Transformation):C(Simulated_Data)                            0.994901           5       380      0.389498  0.855996
# C(model_size):C(Encoding):C(Transformation)                    0.998321           5       380      0.127852  0.986037
# C(model_size):C(Encoding):C(Simulated_Data)                    0.988604           5       380      0.876057  0.497138
# C(model_size):C(Transformation):C(Simulated_Data)              0.987448           5       380      0.966091  0.438379
# C(Encoding):C(Transformation):C(Simulated_Data)                0.98486            5       380      1.16833   0.324129
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.979638           5       380      1.57965   0.164812
# =============================================================  ==========  ========  ========  ============  ========
#
# MANOVAs for Sensitivity + Precision + Accuracy + F1 + MCC:
# =============================================================  ===========  ========  ========  ==============  =========
# Effect                                                               Value    Num DF    Den DF         F Value     Pr > F
# =============================================================  ===========  ========  ========  ==============  =========
# Intercept                                                      0.000114685         5       380  662610          0
# C(model_size)                                                  0.99002             5       380       0.766104   0.574678
# C(Encoding)                                                    0.999028            5       380       0.0739698  0.996088
# C(Transformation)                                              0.994354            5       380       0.43155    0.826575
# C(Simulated_Data)                                              0.9839              5       380       1.24359    0.287991
# C(model_size):C(Encoding)                                      0.999661            5       380       0.0257989  0.999694
# C(model_size):C(Transformation)                                0.998078            5       380       0.146329   0.981061
# C(model_size):C(Simulated_Data)                                0.996405            5       380       0.274177   0.927157
# C(Encoding):C(Transformation)                                  0.991963            5       380       0.615776   0.687876
# C(Encoding):C(Simulated_Data)                                  0.963336            5       380       2.89255    0.0140964
# C(Transformation):C(Simulated_Data)                            0.994171            5       380       0.445584   0.816467
# C(model_size):C(Encoding):C(Transformation)                    0.998174            5       380       0.139033   0.983118
# C(model_size):C(Encoding):C(Simulated_Data)                    0.977095            5       380       1.78162    0.115622
# C(model_size):C(Transformation):C(Simulated_Data)              0.987415            5       380       0.968648   0.436778
# C(Encoding):C(Transformation):C(Simulated_Data)                0.982337            5       380       1.36653    0.236056
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.973336            5       380       2.08197    0.0669082
# =============================================================  ===========  ========  ========  ==============  =========
#
# MANOVAs for Specificity + Sensitivity + Precision + Accuracy + F1 + MCC:
# =============================================================  ===========  ========  ========  =============  ==========
# Effect                                                               Value    Num DF    Den DF        F Value      Pr > F
# =============================================================  ===========  ========  ========  =============  ==========
# Intercept                                                      9.26532e-05         6       379  681691         0
# C(model_size)                                                  0.989836            6       379       0.648638  0.69124
# C(Encoding)                                                    0.991865            6       379       0.518081  0.794651
# C(Transformation)                                              0.994342            6       379       0.35946   0.904216
# C(Simulated_Data)                                              0.979412            6       379       1.32782   0.243589
# C(model_size):C(Encoding)                                      0.99688             6       379       0.197687  0.977351
# C(model_size):C(Transformation)                                0.996061            6       379       0.249776  0.959257
# C(model_size):C(Simulated_Data)                                0.996017            6       379       0.252616  0.958112
# C(Encoding):C(Transformation)                                  0.989571            6       379       0.665693  0.677465
# C(Encoding):C(Simulated_Data)                                  0.955812            6       379       2.92023   0.00851353
# C(Transformation):C(Simulated_Data)                            0.993908            6       379       0.387201  0.887166
# C(model_size):C(Encoding):C(Transformation)                    0.998172            6       379       0.115667  0.994555
# C(model_size):C(Encoding):C(Simulated_Data)                    0.973965            6       379       1.68849   0.122542
# C(model_size):C(Transformation):C(Simulated_Data)              0.987312            6       379       0.811755  0.561245
# C(Encoding):C(Transformation):C(Simulated_Data)                0.979758            6       379       1.30504   0.253801
# C(model_size):C(Encoding):C(Transformation):C(Simulated_Data)  0.971598            6       379       1.8465    0.0890728
# =============================================================  ===========  ========  ========  =============  ==========
