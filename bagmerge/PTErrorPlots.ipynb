# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AllPatients_PTError.csv')
df.head()
# Out:
#    Angle (rad)                                   Axis  Absolute Error (%)
# 0     0.413784  [ 0.79517995 -0.60637352  0.        ]            1.990940
# 1     0.345483  [ 0.96371037 -0.26695002  0.        ]            1.303629
# 2     0.372619  [ 0.93106348 -0.36485721  0.        ]            3.854674
# 3     0.390895  [ 0.90326823 -0.42907635  0.        ]            3.587399
# 4     0.364411  [ 0.75718805 -0.65319695  0.        ]            1.360748

# %%
sns.set_theme(style='darkgrid')
sns.relplot(x='Angle (rad)', y='Absolute Error (%)', data=df.head(5), height=7.5)
